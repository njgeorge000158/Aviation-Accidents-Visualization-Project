# %%
#*******************************************************************************************
 #
 #  File Name:  PyAviationAccidentsTransformSecond.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, PyAviationAccidentsTransformSecond.ipynb, 
 #      uses Pandas as well as other methods to transform the information for use.
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  10/18/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import PySubRoutines as subroutine

import PyAviationAccidentsConstants as local_constant
import PyAviationAccidentsFunctions as local_function

from datetime import datetime as dt

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'PyAviationAccidentsTransformSecond.ipynb'

# %%
log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('PyAviationAccidentsTransformSecond')

# %% [markdown]
# # <br> **Section 1: Data Preparation**

# %% [markdown]
# ## **1.1: Read CSV Files**

# %% [markdown]
# ### **Aviation Accidents**

# %%
cleanAccidentsDataFrame \
    = function. \
        ReturnCSVFileAsDataFrame \
            (local_constant \
                 .AVIATION_UPDATED_ACCIDENTS_DATA_CSV_FILE)

cleanAccidentsDataFrame \
    = cleanAccidentsDataFrame \
        .drop \
            (cleanAccidentsDataFrame.columns[0], 
             axis = 1)


log_function \
    .DebugReturnObjectWriteObject \
        (cleanAccidentsDataFrame)

# %% [markdown]
# ### **Aviation Accident Narratives**

# %%
narrativesDataFrame \
    = function. \
        ReturnCSVFileAsDataFrame \
            (local_constant \
                 .AVIATION_UPDATED_ACCIDENTS_NARRATIVE_CSV_FILE)

narrativesDataFrame \
    = narrativesDataFrame \
        .drop \
            (narrativesDataFrame.columns[0], 
             axis = 1)


log_function \
    .DebugReturnObjectWriteObject \
        (narrativesDataFrame)

# %% [markdown]
# ### **Departure Airports**

# %%
departureAirportsDataFrame \
    = function. \
        ReturnCSVFileAsDataFrame \
            (local_constant \
                 .AVIATION_DEPARTURE_AIRPORTS_CSV_FILE)

departureAirportsDataFrame \
    = departureAirportsDataFrame \
        .drop \
            (departureAirportsDataFrame.columns[0], 
             axis = 1)


log_function \
    .DebugReturnObjectWriteObject \
        (departureAirportsDataFrame)

# %% [markdown]
# ### **Destination Airports**

# %%
destinationAirportsDataFrame \
    = function. \
        ReturnCSVFileAsDataFrame \
            (local_constant \
                 .AVIATION_DESTINATION_AIRPORTS_CSV_FILE)

destinationAirportsDataFrame \
    = destinationAirportsDataFrame \
        .drop \
            (destinationAirportsDataFrame.columns[0], 
             axis = 1)


log_function \
    .DebugReturnObjectWriteObject \
        (destinationAirportsDataFrame)

# %% [markdown]
# ### **Aviation Accident Locations**

# %%
accidentLocationsDataFrame \
    = function. \
        ReturnCSVFileAsDataFrame \
            (local_constant \
                 .AVIATION_ACCIDENT_LOCATIONS_CSV_FILE)

accidentLocationsDataFrame \
    = accidentLocationsDataFrame \
        .drop \
            (accidentLocationsDataFrame.columns[0], 
             axis = 1)


log_function \
    .DebugReturnObjectWriteObject \
        (accidentLocationsDataFrame)

# %% [markdown]
# ## **1.2: Display DataFrames**

# %% [markdown]
# ### **Aviation Accidents**

# %%
captionString \
    = 'Table 1.2.1: Updated Aviation Accidents (1970-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (cleanAccidentsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_79feb caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_79feb_row0_col0, #T_79feb_row0_col1, #T_79feb_row0_col2, #T_79feb_row0_col3, #T_79feb_row0_col4, #T_79feb_row0_col5, #T_79feb_row0_col6, #T_79feb_row0_col7, #T_79feb_row0_col8, #T_79feb_row0_col9, #T_79feb_row0_col10, #T_79feb_row0_col11, #T_79feb_row0_col12, #T_79feb_row1_col0, #T_79feb_row1_col1, #T_79feb_row1_col2, #T_79feb_row1_col3, #T_79feb_row1_col4, #T_79feb_row1_col5, #T_79feb_row1_col6, #T_79feb_row1_col7, #T_79feb_row1_col8, #T_79feb_row1_col9, #T_79feb_row1_col10, #T_79feb_row1_col11, #T_79feb_row1_col12, #T_79feb_row2_col0, #T_79feb_row2_col1, #T_79feb_row2_col2, #T_79feb_row2_col3, #T_79feb_row2_col4, #T_79feb_row2_col5, #T_79feb_row2_col6, #T_79feb_row2_col7, #T_79feb_row2_col8, #T_79feb_row2_col9, #T_79feb_row2_col10, #T_79feb_row2_col11, #T_79feb_row2_col12, #T_79feb_row3_col0, #T_79feb_row3_col1, #T_79feb_row3_col2, #T_79feb_row3_col3, #T_79feb_row3_col4, #T_79feb_row3_col5, #T_79feb_row3_col6, #T_79feb_row3_col7, #T_79feb_row3_col8, #T_79feb_row3_col9, #T_79feb_row3_col10, #T_79feb_row3_col11, #T_79feb_row3_col12, #T_79feb_row4_col0, #T_79feb_row4_col1, #T_79feb_row4_col2, #T_79feb_row4_col3, #T_79feb_row4_col4, #T_79feb_row4_col5, #T_79feb_row4_col6, #T_79feb_row4_col7, #T_79feb_row4_col8, #T_79feb_row4_col9, #T_79feb_row4_col10, #T_79feb_row4_col11, #T_79feb_row4_col12, #T_79feb_row5_col0, #T_79feb_row5_col1, #T_79feb_row5_col2, #T_79feb_row5_col3, #T_79feb_row5_col4, #T_79feb_row5_col5, #T_79feb_row5_col6, #T_79feb_row5_col7, #T_79feb_row5_col8, #T_79feb_row5_col9, #T_79feb_row5_col10, #T_79feb_row5_col11, #T_79feb_row5_col12, #T_79feb_row6_col0, #T_79feb_row6_col1, #T_79feb_row6_col2, #T_79feb_row6_col3, #T_79feb_row6_col4, #T_79feb_row6_col5, #T_79feb_row6_col6, #T_79feb_row6_col7, #T_79feb_row6_col8, #T_79feb_row6_col9, #T_79feb_row6_col10, #T_79feb_row6_col11, #T_79feb_row6_col12, #T_79feb_row7_col0, #T_79feb_row7_col1, #T_79feb_row7_col2, #T_79feb_row7_col3, #T_79feb_row7_col4, #T_79feb_row7_col5, #T_79feb_row7_col6, #T_79feb_row7_col7, #T_79feb_row7_col8, #T_79feb_row7_col9, #T_79feb_row7_col10, #T_79feb_row7_col11, #T_79feb_row7_col12, #T_79feb_row8_col0, #T_79feb_row8_col1, #T_79feb_row8_col2, #T_79feb_row8_col3, #T_79feb_row8_col4, #T_79feb_row8_col5, #T_79feb_row8_col6, #T_79feb_row8_col7, #T_79feb_row8_col8, #T_79feb_row8_col9, #T_79feb_row8_col10, #T_79feb_row8_col11, #T_79feb_row8_col12, #T_79feb_row9_col0, #T_79feb_row9_col1, #T_79feb_row9_col2, #T_79feb_row9_col3, #T_79feb_row9_col4, #T_79feb_row9_col5, #T_79feb_row9_col6, #T_79feb_row9_col7, #T_79feb_row9_col8, #T_79feb_row9_col9, #T_79feb_row9_col10, #T_79feb_row9_col11, #T_79feb_row9_col12, #T_79feb_row10_col0, #T_79feb_row10_col1, #T_79feb_row10_col2, #T_79feb_row10_col3, #T_79feb_row10_col4, #T_79feb_row10_col5, #T_79feb_row10_col6, #T_79feb_row10_col7, #T_79feb_row10_col8, #T_79feb_row10_col9, #T_79feb_row10_col10, #T_79feb_row10_col11, #T_79feb_row10_col12, #T_79feb_row11_col0, #T_79feb_row11_col1, #T_79feb_row11_col2, #T_79feb_row11_col3, #T_79feb_row11_col4, #T_79feb_row11_col5, #T_79feb_row11_col6, #T_79feb_row11_col7, #T_79feb_row11_col8, #T_79feb_row11_col9, #T_79feb_row11_col10, #T_79feb_row11_col11, #T_79feb_row11_col12 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_79feb">
#   <caption>Table 1.2.1: Updated Aviation Accidents (1970-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_79feb_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_79feb_level0_col1" class="col_heading level0 col1" >acc_date</th>
#       <th id="T_79feb_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_79feb_level0_col3" class="col_heading level0 col3" >operator</th>
#       <th id="T_79feb_level0_col4" class="col_heading level0 col4" >registration</th>
#       <th id="T_79feb_level0_col5" class="col_heading level0 col5" >total_fatalities</th>
#       <th id="T_79feb_level0_col6" class="col_heading level0 col6" >total_occupants</th>
#       <th id="T_79feb_level0_col7" class="col_heading level0 col7" >aircraft_damage</th>
#       <th id="T_79feb_level0_col8" class="col_heading level0 col8" >phase</th>
#       <th id="T_79feb_level0_col9" class="col_heading level0 col9" >nature</th>
#       <th id="T_79feb_level0_col10" class="col_heading level0 col10" >depart_airport</th>
#       <th id="T_79feb_level0_col11" class="col_heading level0 col11" >destination_airport</th>
#       <th id="T_79feb_level0_col12" class="col_heading level0 col12" >location</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_79feb_row0_col0" class="data row0 col0" >ACC1003</td>
#       <td id="T_79feb_row0_col1" class="data row0 col1" >1992-07-31</td>
#       <td id="T_79feb_row0_col2" class="data row0 col2" >Yakovlev YAK-42</td>
#       <td id="T_79feb_row0_col3" class="data row0 col3" >China General Aviation Corp.</td>
#       <td id="T_79feb_row0_col4" class="data row0 col4" >B-2755</td>
#       <td id="T_79feb_row0_col5" class="data row0 col5" >107</td>
#       <td id="T_79feb_row0_col6" class="data row0 col6" >126</td>
#       <td id="T_79feb_row0_col7" class="data row0 col7" >Destroyed</td>
#       <td id="T_79feb_row0_col8" class="data row0 col8" >Takeoff (TOF)</td>
#       <td id="T_79feb_row0_col9" class="data row0 col9" >Domestic Scheduled Passenger</td>
#       <td id="T_79feb_row0_col10" class="data row0 col10" >Nanjing Dajiaochang Airport (NKG/ZSNJ), China</td>
#       <td id="T_79feb_row0_col11" class="data row0 col11" >Xiamen Airport (XMN/ZSAM), China</td>
#       <td id="T_79feb_row0_col12" class="data row0 col12" >Nanking Airport (NKG) (China)</td>
#     </tr>
#     <tr>
#       <td id="T_79feb_row1_col0" class="data row1 col0" >ACC1004</td>
#       <td id="T_79feb_row1_col1" class="data row1 col1" >1992-08-27</td>
#       <td id="T_79feb_row1_col2" class="data row1 col2" >Tupolev TU-134</td>
#       <td id="T_79feb_row1_col3" class="data row1 col3" >Aeroflot</td>
#       <td id="T_79feb_row1_col4" class="data row1 col4" >RA-65058</td>
#       <td id="T_79feb_row1_col5" class="data row1 col5" >84</td>
#       <td id="T_79feb_row1_col6" class="data row1 col6" >84</td>
#       <td id="T_79feb_row1_col7" class="data row1 col7" >Destroyed</td>
#       <td id="T_79feb_row1_col8" class="data row1 col8" >Approach (APR)</td>
#       <td id="T_79feb_row1_col9" class="data row1 col9" >Domestic Scheduled Passenger</td>
#       <td id="T_79feb_row1_col10" class="data row1 col10" >Donetsk Airport (DOK/UKCC), Ukraine</td>
#       <td id="T_79feb_row1_col11" class="data row1 col11" >Ivanovo Airport (IWA/UUBI), Russia</td>
#       <td id="T_79feb_row1_col12" class="data row1 col12" >3 km (1.9 mls) SE of Ivanovo Airport (IWA) (Russia)</td>
#     </tr>
#     <tr>
#       <td id="T_79feb_row2_col0" class="data row2 col0" >ACC1005</td>
#       <td id="T_79feb_row2_col1" class="data row2 col1" >1992-08-27</td>
#       <td id="T_79feb_row2_col2" class="data row2 col2" >de Havilland Canada DHC-4</td>
#       <td id="T_79feb_row2_col3" class="data row2 col3" >NewCal Aviation</td>
#       <td id="T_79feb_row2_col4" class="data row2 col4" >N400NC</td>
#       <td id="T_79feb_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_79feb_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_79feb_row2_col7" class="data row2 col7" >Destroyed</td>
#       <td id="T_79feb_row2_col8" class="data row2 col8" >Initial climb (ICL)</td>
#       <td id="T_79feb_row2_col9" class="data row2 col9" >Test</td>
#       <td id="T_79feb_row2_col10" class="data row2 col10" >Gimli Airport, MB (YGM/GYGM), Canada</td>
#       <td id="T_79feb_row2_col11" class="data row2 col11" >Gimli Airport, MB (YGM/GYGM), Canada</td>
#       <td id="T_79feb_row2_col12" class="data row2 col12" >Gimli Airport, MB (YGM) (Canada)</td>
#     </tr>
#     <tr>
#       <td id="T_79feb_row3_col0" class="data row3 col0" >ACC1006</td>
#       <td id="T_79feb_row3_col1" class="data row3 col1" >1992-08-27</td>
#       <td id="T_79feb_row3_col2"

# %% [markdown]
# ### **Aviation Accident Narratives**

# %%
captionString \
    = 'Table 1.2.2: Aviation Accident Narratives (1970-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (narrativesDataFrame.head(5), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_a69bb caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_a69bb_row0_col0, #T_a69bb_row0_col1, #T_a69bb_row1_col0, #T_a69bb_row1_col1, #T_a69bb_row2_col0, #T_a69bb_row2_col1, #T_a69bb_row3_col0, #T_a69bb_row3_col1, #T_a69bb_row4_col0, #T_a69bb_row4_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_a69bb">
#   <caption>Table 1.2.2: Aviation Accident Narratives (1970-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_a69bb_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_a69bb_level0_col1" class="col_heading level0 col1" >narrative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a69bb_row0_col0" class="data row0 col0" >ACC1003</td>
#       <td id="T_a69bb_row0_col1" class="data row0 col1" >China General Aviation Corp. flight 7552, a Yakovlev Yak-42D, was destroyed when it crashed during takeoff from Nanjing Dajiaochang Airport in China. Of the 126 persons on board the flight, 19 survived the accident.The aircraft operated on a scheduled passenger service to Xiamen Airport. During an attempted takeoff from runway 06, the flight failed to rotate, even as the speed increased past Vr speed.The flight crew then attempted to abort the takeoff, but the aircraft overran the runway at high speed. After 420 meters the aircraft crossed a 22 feet wide drainage ditch and impacted a 2 metre high embankment. The aircraft's ground speed at the time was 210 km/h (113 kts). It broke up and caught fire.It was established that the aircraft's horizontal stabiliser was trimmed in the landing configuration. This was not discovered because the crew probably did not perform the pre-flight checklist.</td>
#     </tr>
#     <tr>
#       <td id="T_a69bb_row1_col0" class="data row1 col0" >ACC1004</td>
#       <td id="T_a69bb_row1_col1" class="data row1 col1" >The Tu-134 operated on a passenger flight from Donetsk to Ivanovo. Weather at the destination was poor with a visibility of 1200 m, haze, drizzle, and an overcast at 110 m.The aircraft deviated from the approach procedures and at a distance of 8600 m from the runway the aircraft was at 500 m (instead of 400 m as prescribed) with a lateral deviation of 1900 m to the right at a speed of 390 km/h with flaps and stabilizer not yet configured for final approach. None of the crew members reported the altitude and speed to the commander and the navigator had not given any information to allow the aircraft to align with the runway and glide path. The navigator then suggested the captain to select flaps to 20° and to make a turn to align with the runway. The captain ignored this and continued his approach with performing the necessary actions. While descending through a height of 350 m the GPWS sounded. The flight crew did not react to this warning.At a distance of 4500 m from the runway, the aircraft had a 200300 m lateral deviation from the approach path and had reached a height of 200 m. To reach the landing course, the commander began to turn to the right with a roll of up to 35°. The turn was performed uncoordinated, with the result that the vertical speed increased to 15-16 m/s. The approach continued to be unstabilized and at an altitude of about 80 m the navigator made a last attempt to convince the aircraft commander of the need for a go-around. Two seconds later the captain likely saw trees ahead and attempted a manouvre to avoid a collision.The aircraft struck trees 2962 m from the runway at a speed of 370 km/h and a rate of descent of 6 m/s. At that moment, the plane was 60 meters to the left of the extended runway centreline. The right wing broke up and the aircraft impacted the ground 512 m after the first point of impact.On the ground, a two storey residential house and several non-residential buildings were damaged.</td>
#     </tr>
#     <tr>
#       <td id="T_a69bb_row2_col0" class="data row2 col0" >ACC1005</td>
#       <td id="T_a69bb_row2_col1" class="data row2 col1" >The aircraft had just taken off on an experimental flight when it entered a gradually steepening climb. During the climb the aircraft rolled slowly to the right and, at approximately 200 feet above ground level (agl), it entered a steep nose-down, right-wing-low attitude and crashed. Upon impact, the on-board fuel ignited and the majority of the aircraft wreckage was destroyed by fire. The three crew members aboard the aircraft were fatally injured.The Caribou was the initial aircraft of a modification project by NewCal Aviation that involved the removal of the original Pratt & Whitney R-2000-7M2 piston engines and the installation of Pratt & Whitney PT6A-67R turbo-prop engines and associated equipment. The first flight tests of the modified aircraft began on 16 November 1991. The occurrence flight was intended to be the first of several trips designed to flight-check the fuel and hydraulic systems.</td>
#     </tr>
#     <tr>
#       <td id="T_a69bb_row3_col0" class="data row3 col0" >ACC1006</td>
#       <td id="T_a69bb_row3_col1" class="data row3 col1" >The float-equipped Twin Otter crashed into the jungle 35 yards from the Algodon River when attempting an emergency landing after power loss of the engines. The aircraft had departed Iquitos at 11:25 hours on a flight to El Estrecho, a village on the border with Colombia.The airplane carried the dual military serial FAP304.</td>
#     </tr>
#     <tr>
#       <td id="T_a69bb_row4_col0" class="data row4 col0" >ACC1010</td>
#       <td id="T_a69bb_row4_col1" class="data row4 col1" >The aircraft touched down short of runway 25 at Bellavista Airport (BLP). The right-hand wing and engine broke off and a fire erupted as the aircraft slewed to a stop. The aircraft burned out and all but one of the occupants evacuated alive.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Departure Airports**

# %%
captionString \
    = 'Table 1.2.3: Departure Airports for each Accident (1970-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (departureAirportsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_03e55 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_03e55_row0_col0, #T_03e55_row0_col1, #T_03e55_row0_col2, #T_03e55_row0_col3, #T_03e55_row0_col4, #T_03e55_row0_col5, #T_03e55_row0_col6, #T_03e55_row0_col7, #T_03e55_row0_col8, #T_03e55_row1_col0, #T_03e55_row1_col1, #T_03e55_row1_col2, #T_03e55_row1_col3, #T_03e55_row1_col4, #T_03e55_row1_col5, #T_03e55_row1_col6, #T_03e55_row1_col7, #T_03e55_row1_col8, #T_03e55_row2_col0, #T_03e55_row2_col1, #T_03e55_row2_col2, #T_03e55_row2_col3, #T_03e55_row2_col4, #T_03e55_row2_col5, #T_03e55_row2_col6, #T_03e55_row2_col7, #T_03e55_row2_col8, #T_03e55_row3_col0, #T_03e55_row3_col1, #T_03e55_row3_col2, #T_03e55_row3_col3, #T_03e55_row3_col4, #T_03e55_row3_col5, #T_03e55_row3_col6, #T_03e55_row3_col7, #T_03e55_row3_col8, #T_03e55_row4_col0, #T_03e55_row4_col1, #T_03e55_row4_col2, #T_03e55_row4_col3, #T_03e55_row4_col4, #T_03e55_row4_col5, #T_03e55_row4_col6, #T_03e55_row4_col7, #T_03e55_row4_col8, #T_03e55_row5_col0, #T_03e55_row5_col1, #T_03e55_row5_col2, #T_03e55_row5_col3, #T_03e55_row5_col4, #T_03e55_row5_col5, #T_03e55_row5_col6, #T_03e55_row5_col7, #T_03e55_row5_col8, #T_03e55_row6_col0, #T_03e55_row6_col1, #T_03e55_row6_col2, #T_03e55_row6_col3, #T_03e55_row6_col4, #T_03e55_row6_col5, #T_03e55_row6_col6, #T_03e55_row6_col7, #T_03e55_row6_col8, #T_03e55_row7_col0, #T_03e55_row7_col1, #T_03e55_row7_col2, #T_03e55_row7_col3, #T_03e55_row7_col4, #T_03e55_row7_col5, #T_03e55_row7_col6, #T_03e55_row7_col7, #T_03e55_row7_col8, #T_03e55_row8_col0, #T_03e55_row8_col1, #T_03e55_row8_col2, #T_03e55_row8_col3, #T_03e55_row8_col4, #T_03e55_row8_col5, #T_03e55_row8_col6, #T_03e55_row8_col7, #T_03e55_row8_col8, #T_03e55_row9_col0, #T_03e55_row9_col1, #T_03e55_row9_col2, #T_03e55_row9_col3, #T_03e55_row9_col4, #T_03e55_row9_col5, #T_03e55_row9_col6, #T_03e55_row9_col7, #T_03e55_row9_col8, #T_03e55_row10_col0, #T_03e55_row10_col1, #T_03e55_row10_col2, #T_03e55_row10_col3, #T_03e55_row10_col4, #T_03e55_row10_col5, #T_03e55_row10_col6, #T_03e55_row10_col7, #T_03e55_row10_col8, #T_03e55_row11_col0, #T_03e55_row11_col1, #T_03e55_row11_col2, #T_03e55_row11_col3, #T_03e55_row11_col4, #T_03e55_row11_col5, #T_03e55_row11_col6, #T_03e55_row11_col7, #T_03e55_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_03e55">
#   <caption>Table 1.2.3: Departure Airports for each Accident (1970-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_03e55_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_03e55_level0_col1" class="col_heading level0 col1" >icao</th>
#       <th id="T_03e55_level0_col2" class="col_heading level0 col2" >iata</th>
#       <th id="T_03e55_level0_col3" class="col_heading level0 col3" >name</th>
#       <th id="T_03e55_level0_col4" class="col_heading level0 col4" >state</th>
#       <th id="T_03e55_level0_col5" class="col_heading level0 col5" >country</th>
#       <th id="T_03e55_level0_col6" class="col_heading level0 col6" >country_code</th>
#       <th id="T_03e55_level0_col7" class="col_heading level0 col7" >lat</th>
#       <th id="T_03e55_level0_col8" class="col_heading level0 col8" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_03e55_row0_col0" class="data row0 col0" >ACC1003</td>
#       <td id="T_03e55_row0_col1" class="data row0 col1" >ZSNJ</td>
#       <td id="T_03e55_row0_col2" class="data row0 col2" >NKG</td>
#       <td id="T_03e55_row0_col3" class="data row0 col3" >Nanjing Dajiaochang Airport</td>
#       <td id="T_03e55_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_03e55_row0_col5" class="data row0 col5" >China</td>
#       <td id="T_03e55_row0_col6" class="data row0 col6" >CN</td>
#       <td id="T_03e55_row0_col7" class="data row0 col7" >31.74</td>
#       <td id="T_03e55_row0_col8" class="data row0 col8" >118.86</td>
#     </tr>
#     <tr>
#       <td id="T_03e55_row1_col0" class="data row1 col0" >ACC1004</td>
#       <td id="T_03e55_row1_col1" class="data row1 col1" >UKCC</td>
#       <td id="T_03e55_row1_col2" class="data row1 col2" >DOK</td>
#       <td id="T_03e55_row1_col3" class="data row1 col3" >Donetsk Airport</td>
#       <td id="T_03e55_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_03e55_row1_col5" class="data row1 col5" >Ukraine</td>
#       <td id="T_03e55_row1_col6" class="data row1 col6" >UA</td>
#       <td id="T_03e55_row1_col7" class="data row1 col7" >48.07</td>
#       <td id="T_03e55_row1_col8" class="data row1 col8" >37.74</td>
#     </tr>
#     <tr>
#       <td id="T_03e55_row2_col0" class="data row2 col0" >ACC1005</td>
#       <td id="T_03e55_row2_col1" class="data row2 col1" >GYGM</td>
#       <td id="T_03e55_row2_col2" class="data row2 col2" >YGM</td>
#       <td id="T_03e55_row2_col3" class="data row2 col3" >Gimli Airport</td>
#       <td id="T_03e55_row2_col4" class="data row2 col4" >MB</td>
#       <td id="T_03e55_row2_col5" class="data row2 col5" >Canada</td>
#       <td id="T_03e55_row2_col6" class="data row2 col6" >CA</td>
#       <td id="T_03e55_row2_col7" class="data row2 col7" >50.63</td>
#       <td id="T_03e55_row2_col8" class="data row2 col8" >-97.04</td>
#     </tr>
#     <tr>
#       <td id="T_03e55_row3_col0" class="data row3 col0" >ACC1006</td>
#       <td id="T_03e55_row3_col1" class="data row3 col1" >SPQT</td>
#       <td id="T_03e55_row3_col2" class="data row3 col2" >IQT</td>
#       <td id="T_03e55_row3_col3" class="data row3 col3" >Iquitos Airport</td>
#       <td id="T_03e55_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_03e55_row3_col5" class="data row3 col5" >Peru</td>
#       <td id="T_03e55_row3_col6" class="data row3 col6" >PE</td>
#       <td id="T_03e55_row3_col7" class="data row3 col7" >-3.78</td>
#       <td id="T_03e55_row3_col8" class="data row3 col8" >-73.31</td>
#     </tr>
#     <tr>
#       <td id="T_03e55_row4_col0" class="data row4 col0" >ACC1010</td>
#       <td id="T_03e55_row4_col1" class="data row4 col1" >SPST</td>
#       <td id="T_03e55_row4_col2" class="data row4 col2" >TPP</td>
#       <td id="T_03e55_row4_col3" class="data row4 col3" >Tarapoto Airport</td>
#       <td id="T_03e55_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_03e55_row4_col5" class="data row4 col5" >Peru</td>
#       <td id="T_03e55_row4_col6" class="data row4 col6" >PE</td>
#       <td id="T_03e55_row4_col7" class="data row4 col7" >-6.51</td>
#       <td id="T_03e55_row4_col8" class="data row4 col8" >-76.37</td>
#     </tr>
#     <tr>
#       <td id="T_03e55_row5_col0" class="data row5 col0" >ACC1013</td>
#       <td id="T_03e55_row5_col1" class="data row5 col1" >KSCK</td>
#       <td id="T_03e55_row5_col2" class="data row5 col2" >SCK</td>
#       <td id="T_03e55_row5_col3" class="data row5 col3" >Stockton Airport</td>
#       <td id="T_03e55_row5_col4" class="data row5 col4" >CA</td>
#       <td id="T_03e55_row5_col5" class="data row5 col5" >United States of America</td>
#       <td id="T_03e55_row5_col6" class="data row5 col6" >US</td>
#       <td id="T_03e55_row5_col7" class="data row5 col7" >37.89</td>
#       <td id="T_03e55_row5_col8" class="data row5 col8" >-121.24</td>
#     </tr>
#     <tr>
#       <td id="T_03e55_row6_col0" class="data row6 col0" >ACC1015</td>
#       <td id="T_03e55_row6_col1" class="data row6 col1" >MMPN</td>
#       <td id="T_03e55_row6_col2" class="data row6 col2" >UPN</td>
#       <td id="T_03e55_row6_col3" class="data row6 col3" >Uruapan Airport</td>
#       <td id="T_03e55_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_03e55_row6_col5" class="data row6 col5" >Mexico</td>
#       <td id="T_03e55_row6_col6" class="data row6 col6" >MX</td>
#       <td id="T_03e55_row6_col7" class="data row6 col7" >19.40</td>
#       <td id="T_03e55_row6_col8" class="data row6 col8" >-102.04</td>
#     </tr>
#     <tr>
#       <td id="T_03e55_row7_col0" class="data row7 col0" >ACC1016</td>
#       <td id="T_03e55_row7_col1" class="data row7 col1" >KDAY</td>
#       <td id="T_03e55_row7_col2" class="data row7 col2" >DAY</td>
#       <td id="T_03e55_row7_col3" class="data row7 col3"

# %% [markdown]
# ### **Destination Airports**

# %%
captionString \
    = 'Table 1.2.4: Destination Airports for each Accident (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (destinationAirportsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_8846a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_8846a_row0_col0, #T_8846a_row0_col1, #T_8846a_row0_col2, #T_8846a_row0_col3, #T_8846a_row0_col4, #T_8846a_row0_col5, #T_8846a_row0_col6, #T_8846a_row0_col7, #T_8846a_row0_col8, #T_8846a_row1_col0, #T_8846a_row1_col1, #T_8846a_row1_col2, #T_8846a_row1_col3, #T_8846a_row1_col4, #T_8846a_row1_col5, #T_8846a_row1_col6, #T_8846a_row1_col7, #T_8846a_row1_col8, #T_8846a_row2_col0, #T_8846a_row2_col1, #T_8846a_row2_col2, #T_8846a_row2_col3, #T_8846a_row2_col4, #T_8846a_row2_col5, #T_8846a_row2_col6, #T_8846a_row2_col7, #T_8846a_row2_col8, #T_8846a_row3_col0, #T_8846a_row3_col1, #T_8846a_row3_col2, #T_8846a_row3_col3, #T_8846a_row3_col4, #T_8846a_row3_col5, #T_8846a_row3_col6, #T_8846a_row3_col7, #T_8846a_row3_col8, #T_8846a_row4_col0, #T_8846a_row4_col1, #T_8846a_row4_col2, #T_8846a_row4_col3, #T_8846a_row4_col4, #T_8846a_row4_col5, #T_8846a_row4_col6, #T_8846a_row4_col7, #T_8846a_row4_col8, #T_8846a_row5_col0, #T_8846a_row5_col1, #T_8846a_row5_col2, #T_8846a_row5_col3, #T_8846a_row5_col4, #T_8846a_row5_col5, #T_8846a_row5_col6, #T_8846a_row5_col7, #T_8846a_row5_col8, #T_8846a_row6_col0, #T_8846a_row6_col1, #T_8846a_row6_col2, #T_8846a_row6_col3, #T_8846a_row6_col4, #T_8846a_row6_col5, #T_8846a_row6_col6, #T_8846a_row6_col7, #T_8846a_row6_col8, #T_8846a_row7_col0, #T_8846a_row7_col1, #T_8846a_row7_col2, #T_8846a_row7_col3, #T_8846a_row7_col4, #T_8846a_row7_col5, #T_8846a_row7_col6, #T_8846a_row7_col7, #T_8846a_row7_col8, #T_8846a_row8_col0, #T_8846a_row8_col1, #T_8846a_row8_col2, #T_8846a_row8_col3, #T_8846a_row8_col4, #T_8846a_row8_col5, #T_8846a_row8_col6, #T_8846a_row8_col7, #T_8846a_row8_col8, #T_8846a_row9_col0, #T_8846a_row9_col1, #T_8846a_row9_col2, #T_8846a_row9_col3, #T_8846a_row9_col4, #T_8846a_row9_col5, #T_8846a_row9_col6, #T_8846a_row9_col7, #T_8846a_row9_col8, #T_8846a_row10_col0, #T_8846a_row10_col1, #T_8846a_row10_col2, #T_8846a_row10_col3, #T_8846a_row10_col4, #T_8846a_row10_col5, #T_8846a_row10_col6, #T_8846a_row10_col7, #T_8846a_row10_col8, #T_8846a_row11_col0, #T_8846a_row11_col1, #T_8846a_row11_col2, #T_8846a_row11_col3, #T_8846a_row11_col4, #T_8846a_row11_col5, #T_8846a_row11_col6, #T_8846a_row11_col7, #T_8846a_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_8846a">
#   <caption>Table 1.2.4: Destination Airports for each Accident (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_8846a_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_8846a_level0_col1" class="col_heading level0 col1" >icao</th>
#       <th id="T_8846a_level0_col2" class="col_heading level0 col2" >iata</th>
#       <th id="T_8846a_level0_col3" class="col_heading level0 col3" >name</th>
#       <th id="T_8846a_level0_col4" class="col_heading level0 col4" >state</th>
#       <th id="T_8846a_level0_col5" class="col_heading level0 col5" >country</th>
#       <th id="T_8846a_level0_col6" class="col_heading level0 col6" >country_code</th>
#       <th id="T_8846a_level0_col7" class="col_heading level0 col7" >lat</th>
#       <th id="T_8846a_level0_col8" class="col_heading level0 col8" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8846a_row0_col0" class="data row0 col0" >ACC1003</td>
#       <td id="T_8846a_row0_col1" class="data row0 col1" >ZSAM</td>
#       <td id="T_8846a_row0_col2" class="data row0 col2" >XMN</td>
#       <td id="T_8846a_row0_col3" class="data row0 col3" >Xiamen Airport</td>
#       <td id="T_8846a_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_8846a_row0_col5" class="data row0 col5" >China</td>
#       <td id="T_8846a_row0_col6" class="data row0 col6" >CN</td>
#       <td id="T_8846a_row0_col7" class="data row0 col7" >24.54</td>
#       <td id="T_8846a_row0_col8" class="data row0 col8" >118.13</td>
#     </tr>
#     <tr>
#       <td id="T_8846a_row1_col0" class="data row1 col0" >ACC1004</td>
#       <td id="T_8846a_row1_col1" class="data row1 col1" >UUBI</td>
#       <td id="T_8846a_row1_col2" class="data row1 col2" >IWA</td>
#       <td id="T_8846a_row1_col3" class="data row1 col3" >Ivanovo Airport</td>
#       <td id="T_8846a_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_8846a_row1_col5" class="data row1 col5" >Russia</td>
#       <td id="T_8846a_row1_col6" class="data row1 col6" >RU</td>
#       <td id="T_8846a_row1_col7" class="data row1 col7" >56.94</td>
#       <td id="T_8846a_row1_col8" class="data row1 col8" >40.94</td>
#     </tr>
#     <tr>
#       <td id="T_8846a_row2_col0" class="data row2 col0" >ACC1005</td>
#       <td id="T_8846a_row2_col1" class="data row2 col1" >GYGM</td>
#       <td id="T_8846a_row2_col2" class="data row2 col2" >YGM</td>
#       <td id="T_8846a_row2_col3" class="data row2 col3" >Gimli Airport</td>
#       <td id="T_8846a_row2_col4" class="data row2 col4" >MB</td>
#       <td id="T_8846a_row2_col5" class="data row2 col5" >Canada</td>
#       <td id="T_8846a_row2_col6" class="data row2 col6" >CA</td>
#       <td id="T_8846a_row2_col7" class="data row2 col7" >50.63</td>
#       <td id="T_8846a_row2_col8" class="data row2 col8" >-97.04</td>
#     </tr>
#     <tr>
#       <td id="T_8846a_row3_col0" class="data row3 col0" >ACC1006</td>
#       <td id="T_8846a_row3_col1" class="data row3 col1" >SPEE</td>
#       <td id="T_8846a_row3_col2" class="data row3 col2" >xxx</td>
#       <td id="T_8846a_row3_col3" class="data row3 col3" >El Estrecho Airport</td>
#       <td id="T_8846a_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_8846a_row3_col5" class="data row3 col5" >Peru</td>
#       <td id="T_8846a_row3_col6" class="data row3 col6" >PE</td>
#       <td id="T_8846a_row3_col7" class="data row3 col7" >-2.45</td>
#       <td id="T_8846a_row3_col8" class="data row3 col8" >-72.67</td>
#     </tr>
#     <tr>
#       <td id="T_8846a_row4_col0" class="data row4 col0" >ACC1010</td>
#       <td id="T_8846a_row4_col1" class="data row4 col1" >SPBL</td>
#       <td id="T_8846a_row4_col2" class="data row4 col2" >BLP</td>
#       <td id="T_8846a_row4_col3" class="data row4 col3" >Bellavista Airport</td>
#       <td id="T_8846a_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_8846a_row4_col5" class="data row4 col5" >Peru</td>
#       <td id="T_8846a_row4_col6" class="data row4 col6" >PE</td>
#       <td id="T_8846a_row4_col7" class="data row4 col7" >-7.06</td>
#       <td id="T_8846a_row4_col8" class="data row4 col8" >-76.58</td>
#     </tr>
#     <tr>
#       <td id="T_8846a_row5_col0" class="data row5 col0" >ACC1013</td>
#       <td id="T_8846a_row5_col1" class="data row5 col1" >KSCK</td>
#       <td id="T_8846a_row5_col2" class="data row5 col2" >SCK</td>
#       <td id="T_8846a_row5_col3" class="data row5 col3" >Stockton Airport</td>
#       <td id="T_8846a_row5_col4" class="data row5 col4" >CA</td>
#       <td id="T_8846a_row5_col5" class="data row5 col5" >United States of America</td>
#       <td id="T_8846a_row5_col6" class="data row5 col6" >US</td>
#       <td id="T_8846a_row5_col7" class="data row5 col7" >37.89</td>
#       <td id="T_8846a_row5_col8" class="data row5 col8" >-121.24</td>
#     </tr>
#     <tr>
#       <td id="T_8846a_row6_col0" class="data row6 col0" >ACC1015</td>
#       <td id="T_8846a_row6_col1" class="data row6 col1" >xxxx</td>
#       <td id="T_8846a_row6_col2" class="data row6 col2" >AZG</td>
#       <td id="T_8846a_row6_col3" class="data row6 col3" >Apatzingan Airport</td>
#       <td id="T_8846a_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_8846a_row6_col5" class="data row6 col5" >Mexico</td>
#       <td id="T_8846a_row6_col6" class="data row6 col6" >MX</td>
#       <td id="T_8846a_row6_col7" class="data row6 col7" >19.09</td>
#       <td id="T_8846a_row6_col8" class="data row6 col8" >-102.35</td>
#     </tr>
#     <tr>
#       <td id="T_8846a_row7_col0" class="data row7 col0" >ACC1016</td>
#       <td id="T_8846a_row7_col1" class="data row7 col1" >KBWI</td>
#       <td id="T_8846a_row7_col2" class="data row7 col2" >BWI</td>
#       <td id="T_8846a_row7_col3" class="data row7 col3" >B

# %% [markdown]
# ### **Aviation Accident Locations**

# %%
captionString \
    = 'Table 1.2.5: Aviation Accident Locations (1972-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (accidentLocationsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_75098 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_75098_row0_col0, #T_75098_row0_col1, #T_75098_row0_col2, #T_75098_row0_col3, #T_75098_row0_col4, #T_75098_row0_col5, #T_75098_row0_col6, #T_75098_row0_col7, #T_75098_row0_col8, #T_75098_row1_col0, #T_75098_row1_col1, #T_75098_row1_col2, #T_75098_row1_col3, #T_75098_row1_col4, #T_75098_row1_col5, #T_75098_row1_col6, #T_75098_row1_col7, #T_75098_row1_col8, #T_75098_row2_col0, #T_75098_row2_col1, #T_75098_row2_col2, #T_75098_row2_col3, #T_75098_row2_col4, #T_75098_row2_col5, #T_75098_row2_col6, #T_75098_row2_col7, #T_75098_row2_col8, #T_75098_row3_col0, #T_75098_row3_col1, #T_75098_row3_col2, #T_75098_row3_col3, #T_75098_row3_col4, #T_75098_row3_col5, #T_75098_row3_col6, #T_75098_row3_col7, #T_75098_row3_col8, #T_75098_row4_col0, #T_75098_row4_col1, #T_75098_row4_col2, #T_75098_row4_col3, #T_75098_row4_col4, #T_75098_row4_col5, #T_75098_row4_col6, #T_75098_row4_col7, #T_75098_row4_col8, #T_75098_row5_col0, #T_75098_row5_col1, #T_75098_row5_col2, #T_75098_row5_col3, #T_75098_row5_col4, #T_75098_row5_col5, #T_75098_row5_col6, #T_75098_row5_col7, #T_75098_row5_col8, #T_75098_row6_col0, #T_75098_row6_col1, #T_75098_row6_col2, #T_75098_row6_col3, #T_75098_row6_col4, #T_75098_row6_col5, #T_75098_row6_col6, #T_75098_row6_col7, #T_75098_row6_col8, #T_75098_row7_col0, #T_75098_row7_col1, #T_75098_row7_col2, #T_75098_row7_col3, #T_75098_row7_col4, #T_75098_row7_col5, #T_75098_row7_col6, #T_75098_row7_col7, #T_75098_row7_col8, #T_75098_row8_col0, #T_75098_row8_col1, #T_75098_row8_col2, #T_75098_row8_col3, #T_75098_row8_col4, #T_75098_row8_col5, #T_75098_row8_col6, #T_75098_row8_col7, #T_75098_row8_col8, #T_75098_row9_col0, #T_75098_row9_col1, #T_75098_row9_col2, #T_75098_row9_col3, #T_75098_row9_col4, #T_75098_row9_col5, #T_75098_row9_col6, #T_75098_row9_col7, #T_75098_row9_col8, #T_75098_row10_col0, #T_75098_row10_col1, #T_75098_row10_col2, #T_75098_row10_col3, #T_75098_row10_col4, #T_75098_row10_col5, #T_75098_row10_col6, #T_75098_row10_col7, #T_75098_row10_col8, #T_75098_row11_col0, #T_75098_row11_col1, #T_75098_row11_col2, #T_75098_row11_col3, #T_75098_row11_col4, #T_75098_row11_col5, #T_75098_row11_col6, #T_75098_row11_col7, #T_75098_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_75098">
#   <caption>Table 1.2.5: Aviation Accident Locations (1972-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_75098_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_75098_level0_col1" class="col_heading level0 col1" >icao</th>
#       <th id="T_75098_level0_col2" class="col_heading level0 col2" >iata</th>
#       <th id="T_75098_level0_col3" class="col_heading level0 col3" >name</th>
#       <th id="T_75098_level0_col4" class="col_heading level0 col4" >state</th>
#       <th id="T_75098_level0_col5" class="col_heading level0 col5" >country</th>
#       <th id="T_75098_level0_col6" class="col_heading level0 col6" >country_code</th>
#       <th id="T_75098_level0_col7" class="col_heading level0 col7" >lat</th>
#       <th id="T_75098_level0_col8" class="col_heading level0 col8" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_75098_row0_col0" class="data row0 col0" >ACC1003</td>
#       <td id="T_75098_row0_col1" class="data row0 col1" >xxxx</td>
#       <td id="T_75098_row0_col2" class="data row0 col2" >NKG</td>
#       <td id="T_75098_row0_col3" class="data row0 col3" >Nanking Airport</td>
#       <td id="T_75098_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_75098_row0_col5" class="data row0 col5" >China</td>
#       <td id="T_75098_row0_col6" class="data row0 col6" >CN</td>
#       <td id="T_75098_row0_col7" class="data row0 col7" >31.74</td>
#       <td id="T_75098_row0_col8" class="data row0 col8" >118.86</td>
#     </tr>
#     <tr>
#       <td id="T_75098_row1_col0" class="data row1 col0" >ACC1004</td>
#       <td id="T_75098_row1_col1" class="data row1 col1" >xxxx</td>
#       <td id="T_75098_row1_col2" class="data row1 col2" >IWA</td>
#       <td id="T_75098_row1_col3" class="data row1 col3" >Ivanovo Airport</td>
#       <td id="T_75098_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_75098_row1_col5" class="data row1 col5" >Russia</td>
#       <td id="T_75098_row1_col6" class="data row1 col6" >RU</td>
#       <td id="T_75098_row1_col7" class="data row1 col7" >56.92</td>
#       <td id="T_75098_row1_col8" class="data row1 col8" >40.96</td>
#     </tr>
#     <tr>
#       <td id="T_75098_row2_col0" class="data row2 col0" >ACC1005</td>
#       <td id="T_75098_row2_col1" class="data row2 col1" >xxxx</td>
#       <td id="T_75098_row2_col2" class="data row2 col2" >YGM</td>
#       <td id="T_75098_row2_col3" class="data row2 col3" >Gimli Airport</td>
#       <td id="T_75098_row2_col4" class="data row2 col4" >MB</td>
#       <td id="T_75098_row2_col5" class="data row2 col5" >Canada</td>
#       <td id="T_75098_row2_col6" class="data row2 col6" >CA</td>
#       <td id="T_75098_row2_col7" class="data row2 col7" >50.63</td>
#       <td id="T_75098_row2_col8" class="data row2 col8" >-97.04</td>
#     </tr>
#     <tr>
#       <td id="T_75098_row3_col0" class="data row3 col0" >ACC1006</td>
#       <td id="T_75098_row3_col1" class="data row3 col1" >xxxx</td>
#       <td id="T_75098_row3_col2" class="data row3 col2" >xxx</td>
#       <td id="T_75098_row3_col3" class="data row3 col3" >San Antonio del Estrecho</td>
#       <td id="T_75098_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_75098_row3_col5" class="data row3 col5" >Peru</td>
#       <td id="T_75098_row3_col6" class="data row3 col6" >PE</td>
#       <td id="T_75098_row3_col7" class="data row3 col7" >-12.64</td>
#       <td id="T_75098_row3_col8" class="data row3 col8" >-76.65</td>
#     </tr>
#     <tr>
#       <td id="T_75098_row4_col0" class="data row4 col0" >ACC1010</td>
#       <td id="T_75098_row4_col1" class="data row4 col1" >xxxx</td>
#       <td id="T_75098_row4_col2" class="data row4 col2" >BLP</td>
#       <td id="T_75098_row4_col3" class="data row4 col3" >Bellavista Airport</td>
#       <td id="T_75098_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_75098_row4_col5" class="data row4 col5" >Peru</td>
#       <td id="T_75098_row4_col6" class="data row4 col6" >PE</td>
#       <td id="T_75098_row4_col7" class="data row4 col7" >-7.06</td>
#       <td id="T_75098_row4_col8" class="data row4 col8" >-76.58</td>
#     </tr>
#     <tr>
#       <td id="T_75098_row5_col0" class="data row5 col0" >ACC1013</td>
#       <td id="T_75098_row5_col1" class="data row5 col1" >xxxx</td>
#       <td id="T_75098_row5_col2" class="data row5 col2" >xxx</td>
#       <td id="T_75098_row5_col3" class="data row5 col3" >Union Valley Reservoir</td>
#       <td id="T_75098_row5_col4" class="data row5 col4" >CA</td>
#       <td id="T_75098_row5_col5" class="data row5 col5" >United States</td>
#       <td id="T_75098_row5_col6" class="data row5 col6" >US</td>
#       <td id="T_75098_row5_col7" class="data row5 col7" >33.88</td>
#       <td id="T_75098_row5_col8" class="data row5 col8" >-117.08</td>
#     </tr>
#     <tr>
#       <td id="T_75098_row6_col0" class="data row6 col0" >ACC1015</td>
#       <td id="T_75098_row6_col1" class="data row6 col1" >xxxx</td>
#       <td id="T_75098_row6_col2" class="data row6 col2" >UPN</td>
#       <td id="T_75098_row6_col3" class="data row6 col3" >Uruapan Airport</td>
#       <td id="T_75098_row6_col4" class="data row6 col4" >nan</td>
#       <td id="T_75098_row6_col5" class="data row6 col5" >Mexico</td>
#       <td id="T_75098_row6_col6" class="data row6 col6" >MX</td>
#       <td id="T_75098_row6_col7" class="data row6 col7" >19.40</td>
#       <td id="T_75098_row6_col8" class="data row6 col8" >-102.04</td>
#     </tr>
#     <tr>
#       <td id="T_75098_row7_col0" class="data row7 col0" >ACC1016</td>
#       <td id="T_75098_row7_col1" class="data row7 col1" >xxxx</td>
#       <td id="T_75098_row7_col2" class="data row7 col2" >xxx</td>
#       <td id="T_75098_row7_col3" class="data row7 col3" >Elkridge</td>

# %% [markdown]
# # <br> **Section 2: Create DataFrames for Database Tables**

# %% [markdown]
# ## **2.1: Aviation Accidents**

# %% [markdown]
# ### **Extract Clean Aviation Accidents Data**

# %%
finalAccidentsDataFrame \
    = cleanAccidentsDataFrame \
            [['accident_id',
              'acc_date',
              'type', 
              'operator', 
              'total_fatalities',
              'total_occupants',
              'aircraft_damage',
              'phase',
              'nature',
              'location']] \
        .copy()


log_function \
    .DebugReturnObjectWriteObject \
        (finalAccidentsDataFrame)

# %% [markdown]
# ### **Extract Departure Airport Names**

# %%
finalAccidentsDataFrame \
    ['departure'] \
        = departureAirportsDataFrame \
            ['name'] \
                .copy()


log_function \
    .DebugReturnObjectWriteObject \
        (finalAccidentsDataFrame)

# %% [markdown]
# ### **Extract Destination Airport Names**

# %%
finalAccidentsDataFrame \
    ['destination'] \
        = destinationAirportsDataFrame \
            ['name'] \
                .copy()


log_function \
    .DebugReturnObjectWriteObject \
        (finalAccidentsDataFrame)

# %% [markdown]
# ### **Extract Accident Location Information**

# %%
finalAccidentsDataFrame \
    [['place',
      'state',
      'country',
      'country_code',
      'lat', 
      'lon']] \
        = accidentLocationsDataFrame \
            [['name',
              'state',
              'country',
              'country_code',
              'lat',
              'lon']]

log_function \
    .DebugReturnObjectWriteObject \
        (finalAccidentsDataFrame)

# %% [markdown]
# ### **Extract Accident Narrative Information**

# %%
finalAccidentsDataFrame \
    ['narrative'] \
        = narrativesDataFrame \
            ['narrative']


log_function \
    .DebugReturnObjectWriteObject \
        (finalAccidentsDataFrame)

# %% [markdown]
# ### **Extract Year From Date Column**

# %%
finalAccidentsDataFrame \
    ['acc_date'] \
        = pd.to_datetime \
            (finalAccidentsDataFrame \
                 ['acc_date'], 
             format = '%Y-%m-%d')

finalAccidentsDataFrame \
    ['year'] \
        = finalAccidentsDataFrame \
            ['acc_date'] \
                .dt.year


finalAccidentsDataFrame \
    ['acc_date'] \
        = finalAccidentsDataFrame \
            ['acc_date'] \
                .astype(str)

finalAccidentsDataFrame \
    ['year'] \
        = finalAccidentsDataFrame \
            ['year'] \
                .astype(str)


log_function \
    .DebugReturnObjectWriteObject \
        (finalAccidentsDataFrame)

# %% [markdown]
# ### **Rename DataFrame Columns**

# %%
finalAccidentsDataFrame \
    = finalAccidentsDataFrame \
        .rename \
            ({'acc_date': 'date', 
              'total_fatalities': 'fatalities', 
              'total_occupants': 'occupants',
              'aircraft_damage': 'damage'}, 
             axis = 1)


log_function \
    .DebugReturnObjectWriteObject \
        (finalAccidentsDataFrame)

# %% [markdown]
# ### **Reorder DataFrame Columns**

# %%
finalAccidentsDataFrame \
    = finalAccidentsDataFrame \
        [['accident_id',
          'date',
          'year',
          'type',
          'operator',
          'fatalities',
          'occupants',
          'damage',
          'phase',
          'nature',
          'departure',
          'destination',
          'location',
          'place',
          'state',
          'country',
          'country_code',
          'lat',
          'lon',
          'narrative']]
 
finalAccidentsDataFrame \
    = finalAccidentsDataFrame \
        .reset_index \
            (drop = True)


log_function \
    .DebugReturnObjectWriteObject \
        (finalAccidentsDataFrame)

# %% [markdown]
# ## **2.2: Country**

# %%
countryDataFrame \
    = local_function \
        .ReturnCountryDataFrame()


log_function \
    .DebugReturnObjectWriteObject \
        (countryDataFrame)

# %%
# This function call double checks that the country names 
# are standardized.
finalAccidentsDataFrame \
    = local_function \
        .ReturnStandardizedCountryNames \
            (finalAccidentsDataFrame,
             countryDataFrame,
             'country_code',
             'country')


log_function \
    .DebugReturnObjectWriteObject \
        (finalAccidentsDataFrame)

# %% [markdown]
# ## **2.3: Aircraft Types**

# %%
tempList \
    = finalAccidentsDataFrame \
            ['type'] \
        .unique() \
        .tolist()

typesSortedStringList \
    = sorted \
        (tempList)

typesDataFrame \
    = pd.DataFrame \
        (typesSortedStringList, 
         columns = ['type']) 
    
    
log_function \
    .DebugReturnObjectWriteObject \
        (typesDataFrame)

# %% [markdown]
# ## **2.4: Aircraft Operators**

# %%
tempList \
    = finalAccidentsDataFrame \
            ['operator'] \
        .unique() \
        .tolist()

operatorsSortedStringList \
    = sorted \
        (tempList)

operatorsDataFrame \
    = pd.DataFrame \
        (operatorsSortedStringList, 
         columns = ['operator']) 
    
    
log_function \
    .DebugReturnObjectWriteObject \
        (operatorsDataFrame)

# %% [markdown]
# ## **2.5: Aircraft Damage**

# %%
tempList \
    = finalAccidentsDataFrame \
            ['damage'] \
        .unique() \
        .tolist()

damageSortedStringList \
    = sorted \
        (tempList)

damageDataFrame \
    = pd.DataFrame \
        (damageSortedStringList, 
         columns = ['damage']) 
    
    
log_function \
    .DebugReturnObjectWriteObject \
        (damageDataFrame)

# %% [markdown]
# ## **2.6: Flight Phase**

# %%
tempList \
    = finalAccidentsDataFrame \
            ['phase'] \
        .unique() \
        .tolist()

phaseSortedStringList \
    = sorted \
        (tempList)

phaseDataFrame \
    = pd.DataFrame \
        (phaseSortedStringList, 
         columns = ['phase']) 
    
    
log_function \
    .DebugReturnObjectWriteObject \
        (phaseDataFrame)

# %% [markdown]
# ## **2.7: Nature of Flight**

# %%
tempList \
    = finalAccidentsDataFrame \
            ['nature'] \
        .unique() \
        .tolist()

natureSortedStringList \
    = sorted \
        (tempList)

natureDataFrame \
    = pd.DataFrame \
        (natureSortedStringList, 
         columns = ['nature']) 
    
    
log_function \
    .DebugReturnObjectWriteObject \
        (natureDataFrame)

# %% [markdown]
# ## **2.8: Airports**

# %%
airportsDataFrame \
    = None


airportsDataFrame \
    = pd.concat \
        ([departureAirportsDataFrame.copy(), 
          destinationAirportsDataFrame.copy()],
         axis = 0)

airportsDataFrame \
    .drop \
        (columns \
             = ['accident_id'],
         axis = 1,
         inplace = True)

airportsDataFrame \
    = airportsDataFrame \
        .drop_duplicates \
            (subset \
                 = ['name',
                    'country'])

airportsDataFrame \
    .reset_index \
        (drop = True)


log_function \
    .DebugReturnObjectWriteObject \
        (airportsDataFrame)

# %% [markdown]
# ## **2.9: Departure Airports**

# %%
updatedDepartureAirportsDataFrame \
    = departureAirportsDataFrame \
        .copy()

updatedDepartureAirportsDataFrame \
    [['date', 
      'year']] \
        = finalAccidentsDataFrame \
            [['date',
              'year']]

updatedDepartureAirportsDataFrame \
    = updatedDepartureAirportsDataFrame \
        [['accident_id',
          'date',
          'year',
          'icao',
          'iata',
          'name',
          'state',
          'country',
          'country_code',
          'lat',
          'lon']]


log_function \
    .DebugReturnObjectWriteObject \
        (updatedDepartureAirportsDataFrame)

# %% [markdown]
# ## **2.10: Destination Airports**

# %%
updatedDestinationAirportsDataFrame \
    = destinationAirportsDataFrame \
        .copy()

updatedDestinationAirportsDataFrame \
    [['date', 
      'year']] \
        = finalAccidentsDataFrame \
            [['date',
              'year']]

updatedDestinationAirportsDataFrame \
    = updatedDestinationAirportsDataFrame \
        [['accident_id',
          'date',
          'year',
          'icao',
          'iata',
          'name',
          'state',
          'country',
          'country_code',
          'lat',
          'lon']]


log_function \
    .DebugReturnObjectWriteObject \
        (updatedDestinationAirportsDataFrame)

# %% [markdown]
# # <br> **Section 3: Display DataFrames for Database Tables**

# %% [markdown]
# ## **3.1: Aviation Accidents**

# %%
captionString \
    = 'Table 3.1: Final Aviation Accidents DataFrame (1970-2022)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (finalAccidentsDataFrame.head(5), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_46de3 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_46de3_row0_col0, #T_46de3_row0_col1, #T_46de3_row0_col2, #T_46de3_row0_col3, #T_46de3_row0_col4, #T_46de3_row0_col5, #T_46de3_row0_col6, #T_46de3_row0_col7, #T_46de3_row0_col8, #T_46de3_row0_col9, #T_46de3_row0_col10, #T_46de3_row0_col11, #T_46de3_row0_col12, #T_46de3_row0_col13, #T_46de3_row0_col14, #T_46de3_row0_col15, #T_46de3_row0_col16, #T_46de3_row0_col17, #T_46de3_row0_col18, #T_46de3_row0_col19, #T_46de3_row1_col0, #T_46de3_row1_col1, #T_46de3_row1_col2, #T_46de3_row1_col3, #T_46de3_row1_col4, #T_46de3_row1_col5, #T_46de3_row1_col6, #T_46de3_row1_col7, #T_46de3_row1_col8, #T_46de3_row1_col9, #T_46de3_row1_col10, #T_46de3_row1_col11, #T_46de3_row1_col12, #T_46de3_row1_col13, #T_46de3_row1_col14, #T_46de3_row1_col15, #T_46de3_row1_col16, #T_46de3_row1_col17, #T_46de3_row1_col18, #T_46de3_row1_col19, #T_46de3_row2_col0, #T_46de3_row2_col1, #T_46de3_row2_col2, #T_46de3_row2_col3, #T_46de3_row2_col4, #T_46de3_row2_col5, #T_46de3_row2_col6, #T_46de3_row2_col7, #T_46de3_row2_col8, #T_46de3_row2_col9, #T_46de3_row2_col10, #T_46de3_row2_col11, #T_46de3_row2_col12, #T_46de3_row2_col13, #T_46de3_row2_col14, #T_46de3_row2_col15, #T_46de3_row2_col16, #T_46de3_row2_col17, #T_46de3_row2_col18, #T_46de3_row2_col19, #T_46de3_row3_col0, #T_46de3_row3_col1, #T_46de3_row3_col2, #T_46de3_row3_col3, #T_46de3_row3_col4, #T_46de3_row3_col5, #T_46de3_row3_col6, #T_46de3_row3_col7, #T_46de3_row3_col8, #T_46de3_row3_col9, #T_46de3_row3_col10, #T_46de3_row3_col11, #T_46de3_row3_col12, #T_46de3_row3_col13, #T_46de3_row3_col14, #T_46de3_row3_col15, #T_46de3_row3_col16, #T_46de3_row3_col17, #T_46de3_row3_col18, #T_46de3_row3_col19, #T_46de3_row4_col0, #T_46de3_row4_col1, #T_46de3_row4_col2, #T_46de3_row4_col3, #T_46de3_row4_col4, #T_46de3_row4_col5, #T_46de3_row4_col6, #T_46de3_row4_col7, #T_46de3_row4_col8, #T_46de3_row4_col9, #T_46de3_row4_col10, #T_46de3_row4_col11, #T_46de3_row4_col12, #T_46de3_row4_col13, #T_46de3_row4_col14, #T_46de3_row4_col15, #T_46de3_row4_col16, #T_46de3_row4_col17, #T_46de3_row4_col18, #T_46de3_row4_col19 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_46de3">
#   <caption>Table 3.1: Final Aviation Accidents DataFrame (1970-2022)</caption>
#   <thead>
#     <tr>
#       <th id="T_46de3_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_46de3_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_46de3_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_46de3_level0_col3" class="col_heading level0 col3" >type</th>
#       <th id="T_46de3_level0_col4" class="col_heading level0 col4" >operator</th>
#       <th id="T_46de3_level0_col5" class="col_heading level0 col5" >fatalities</th>
#       <th id="T_46de3_level0_col6" class="col_heading level0 col6" >occupants</th>
#       <th id="T_46de3_level0_col7" class="col_heading level0 col7" >damage</th>
#       <th id="T_46de3_level0_col8" class="col_heading level0 col8" >phase</th>
#       <th id="T_46de3_level0_col9" class="col_heading level0 col9" >nature</th>
#       <th id="T_46de3_level0_col10" class="col_heading level0 col10" >departure</th>
#       <th id="T_46de3_level0_col11" class="col_heading level0 col11" >destination</th>
#       <th id="T_46de3_level0_col12" class="col_heading level0 col12" >location</th>
#       <th id="T_46de3_level0_col13" class="col_heading level0 col13" >place</th>
#       <th id="T_46de3_level0_col14" class="col_heading level0 col14" >state</th>
#       <th id="T_46de3_level0_col15" class="col_heading level0 col15" >country</th>
#       <th id="T_46de3_level0_col16" class="col_heading level0 col16" >country_code</th>
#       <th id="T_46de3_level0_col17" class="col_heading level0 col17" >lat</th>
#       <th id="T_46de3_level0_col18" class="col_heading level0 col18" >lon</th>
#       <th id="T_46de3_level0_col19" class="col_heading level0 col19" >narrative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46de3_row0_col0" class="data row0 col0" >ACC1003</td>
#       <td id="T_46de3_row0_col1" class="data row0 col1" >1992-07-31</td>
#       <td id="T_46de3_row0_col2" class="data row0 col2" >1992</td>
#       <td id="T_46de3_row0_col3" class="data row0 col3" >Yakovlev YAK-42</td>
#       <td id="T_46de3_row0_col4" class="data row0 col4" >China General Aviation Corp.</td>
#       <td id="T_46de3_row0_col5" class="data row0 col5" >107</td>
#       <td id="T_46de3_row0_col6" class="data row0 col6" >126</td>
#       <td id="T_46de3_row0_col7" class="data row0 col7" >Destroyed</td>
#       <td id="T_46de3_row0_col8" class="data row0 col8" >Takeoff (TOF)</td>
#       <td id="T_46de3_row0_col9" class="data row0 col9" >Domestic Scheduled Passenger</td>
#       <td id="T_46de3_row0_col10" class="data row0 col10" >Nanjing Dajiaochang Airport</td>
#       <td id="T_46de3_row0_col11" class="data row0 col11" >Xiamen Airport</td>
#       <td id="T_46de3_row0_col12" class="data row0 col12" >Nanking Airport (NKG) (China)</td>
#       <td id="T_46de3_row0_col13" class="data row0 col13" >Nanking Airport</td>
#       <td id="T_46de3_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_46de3_row0_col15" class="data row0 col15" >China</td>
#       <td id="T_46de3_row0_col16" class="data row0 col16" >CN</td>
#       <td id="T_46de3_row0_col17" class="data row0 col17" >31.74</td>
#       <td id="T_46de3_row0_col18" class="data row0 col18" >118.86</td>
#       <td id="T_46de3_row0_col19" class="data row0 col19" >China General Aviation Corp. flight 7552, a Yakovlev Yak-42D, was destroyed when it crashed during takeoff from Nanjing Dajiaochang Airport in China. Of the 126 persons on board the flight, 19 survived the accident.The aircraft operated on a scheduled passenger service to Xiamen Airport. During an attempted takeoff from runway 06, the flight failed to rotate, even as the speed increased past Vr speed.The flight crew then attempted to abort the takeoff, but the aircraft overran the runway at high speed. After 420 meters the aircraft crossed a 22 feet wide drainage ditch and impacted a 2 metre high embankment. The aircraft's ground speed at the time was 210 km/h (113 kts). It broke up and caught fire.It was established that the aircraft's horizontal stabiliser was trimmed in the landing configuration. This was not discovered because the crew probably did not perform the pre-flight checklist.</td>
#     </tr>
#     <tr>
#       <td id="T_46de3_row1_col0" class="data row1 col0" >ACC1004</td>
#       <td id="T_46de3_row1_col1" class="data row1 col1" >1992-08-27</td>
#       <td id="T_46de3_row1_col2" class="data row1 col2" >1992</td>
#       <td id="T_46de3_row1_col3" class="data row1 col3" >Tupolev TU-134</td>
#       <td id="T_46de3_row1_col4" class="data row1 col4" >Aeroflot</td>
#       <td id="T_46de3_row1_col5" class="data row1 col5" >84</td>
#       <td id="T_46de3_row1_col6" class="data row1 col6" >84</td>
#       <td id="T_46de3_row1_col7" class="data row1 col7" >Destroyed</td>
#       <td id="T_46de3_row1_col8" class="data row1 col8" >Approach (APR)</td>
#       <td id="T_46de3_row1_col9" class="data row1 col9" >Domestic Scheduled Passenger</td>
#       <td id="T_46de3_row1_col10" class="data row1 col10" >Donetsk Airport</td>
#       <td id="T_46de3_row1_col11" class="data row1 col11" >Ivanovo Airport</td>
#       <td id="T_46de3_row1_col12" class="data row1 col12" >3 km (1.9 mls) SE of Ivanovo Airport (IWA) (Russia)</td>
#       <td id="T_46de3_row1_col13" class="data row1 col13" >Ivanovo Airport</td>
#       <td id="T_46de3_row1_col14" class="data row1 col14" >nan</td>
#       <td id="T_46de3_row1_col15" class="data row1 col15" >Russia</td>
#       <td id="T_46de3_row1_col16" class="data row1 col16" >RU</td>
#       <td id="T_46de3_row1_col17" class="data row1 col17" >56.92</td>
#       <td id="T_46de3_row1_col18" class="data row1 col18" >40.96</td>
#       <td id="T_46de3_row1_col19" class="data row1 col19" >The Tu-134 operated on a passenger fli

# %% [markdown]
# ## **3.2: Country**

# %%
captionString \
    = 'Table 3.2: Country DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (countryDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_d6a48 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d6a48_row0_col0, #T_d6a48_row0_col1, #T_d6a48_row0_col2, #T_d6a48_row0_col3, #T_d6a48_row0_col4, #T_d6a48_row0_col5, #T_d6a48_row0_col6, #T_d6a48_row0_col7, #T_d6a48_row1_col0, #T_d6a48_row1_col1, #T_d6a48_row1_col2, #T_d6a48_row1_col3, #T_d6a48_row1_col4, #T_d6a48_row1_col5, #T_d6a48_row1_col6, #T_d6a48_row1_col7, #T_d6a48_row2_col0, #T_d6a48_row2_col1, #T_d6a48_row2_col2, #T_d6a48_row2_col3, #T_d6a48_row2_col4, #T_d6a48_row2_col5, #T_d6a48_row2_col6, #T_d6a48_row2_col7, #T_d6a48_row3_col0, #T_d6a48_row3_col1, #T_d6a48_row3_col2, #T_d6a48_row3_col3, #T_d6a48_row3_col4, #T_d6a48_row3_col5, #T_d6a48_row3_col6, #T_d6a48_row3_col7, #T_d6a48_row4_col0, #T_d6a48_row4_col1, #T_d6a48_row4_col2, #T_d6a48_row4_col3, #T_d6a48_row4_col4, #T_d6a48_row4_col5, #T_d6a48_row4_col6, #T_d6a48_row4_col7, #T_d6a48_row5_col0, #T_d6a48_row5_col1, #T_d6a48_row5_col2, #T_d6a48_row5_col3, #T_d6a48_row5_col4, #T_d6a48_row5_col5, #T_d6a48_row5_col6, #T_d6a48_row5_col7, #T_d6a48_row6_col0, #T_d6a48_row6_col1, #T_d6a48_row6_col2, #T_d6a48_row6_col3, #T_d6a48_row6_col4, #T_d6a48_row6_col5, #T_d6a48_row6_col6, #T_d6a48_row6_col7, #T_d6a48_row7_col0, #T_d6a48_row7_col1, #T_d6a48_row7_col2, #T_d6a48_row7_col3, #T_d6a48_row7_col4, #T_d6a48_row7_col5, #T_d6a48_row7_col6, #T_d6a48_row7_col7, #T_d6a48_row8_col0, #T_d6a48_row8_col1, #T_d6a48_row8_col2, #T_d6a48_row8_col3, #T_d6a48_row8_col4, #T_d6a48_row8_col5, #T_d6a48_row8_col6, #T_d6a48_row8_col7, #T_d6a48_row9_col0, #T_d6a48_row9_col1, #T_d6a48_row9_col2, #T_d6a48_row9_col3, #T_d6a48_row9_col4, #T_d6a48_row9_col5, #T_d6a48_row9_col6, #T_d6a48_row9_col7, #T_d6a48_row10_col0, #T_d6a48_row10_col1, #T_d6a48_row10_col2, #T_d6a48_row10_col3, #T_d6a48_row10_col4, #T_d6a48_row10_col5, #T_d6a48_row10_col6, #T_d6a48_row10_col7, #T_d6a48_row11_col0, #T_d6a48_row11_col1, #T_d6a48_row11_col2, #T_d6a48_row11_col3, #T_d6a48_row11_col4, #T_d6a48_row11_col5, #T_d6a48_row11_col6, #T_d6a48_row11_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_d6a48">
#   <caption>Table 3.2: Country DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_d6a48_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_d6a48_level0_col1" class="col_heading level0 col1" >country_code</th>
#       <th id="T_d6a48_level0_col2" class="col_heading level0 col2" >country_code3</th>
#       <th id="T_d6a48_level0_col3" class="col_heading level0 col3" >capital</th>
#       <th id="T_d6a48_level0_col4" class="col_heading level0 col4" >region</th>
#       <th id="T_d6a48_level0_col5" class="col_heading level0 col5" >subregion</th>
#       <th id="T_d6a48_level0_col6" class="col_heading level0 col6" >lat</th>
#       <th id="T_d6a48_level0_col7" class="col_heading level0 col7" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d6a48_row0_col0" class="data row0 col0" >Monaco</td>
#       <td id="T_d6a48_row0_col1" class="data row0 col1" >MC</td>
#       <td id="T_d6a48_row0_col2" class="data row0 col2" >MCO</td>
#       <td id="T_d6a48_row0_col3" class="data row0 col3" >Monaco</td>
#       <td id="T_d6a48_row0_col4" class="data row0 col4" >Europe</td>
#       <td id="T_d6a48_row0_col5" class="data row0 col5" >Western Europe</td>
#       <td id="T_d6a48_row0_col6" class="data row0 col6" >43.73</td>
#       <td id="T_d6a48_row0_col7" class="data row0 col7" >7.43</td>
#     </tr>
#     <tr>
#       <td id="T_d6a48_row1_col0" class="data row1 col0" >Norway</td>
#       <td id="T_d6a48_row1_col1" class="data row1 col1" >NO</td>
#       <td id="T_d6a48_row1_col2" class="data row1 col2" >NOR</td>
#       <td id="T_d6a48_row1_col3" class="data row1 col3" >Oslo</td>
#       <td id="T_d6a48_row1_col4" class="data row1 col4" >Europe</td>
#       <td id="T_d6a48_row1_col5" class="data row1 col5" >Northern Europe</td>
#       <td id="T_d6a48_row1_col6" class="data row1 col6" >59.91</td>
#       <td id="T_d6a48_row1_col7" class="data row1 col7" >10.74</td>
#     </tr>
#     <tr>
#       <td id="T_d6a48_row2_col0" class="data row2 col0" >Greenland</td>
#       <td id="T_d6a48_row2_col1" class="data row2 col1" >GL</td>
#       <td id="T_d6a48_row2_col2" class="data row2 col2" >GRL</td>
#       <td id="T_d6a48_row2_col3" class="data row2 col3" >Nuuk</td>
#       <td id="T_d6a48_row2_col4" class="data row2 col4" >Americas</td>
#       <td id="T_d6a48_row2_col5" class="data row2 col5" >Northern America</td>
#       <td id="T_d6a48_row2_col6" class="data row2 col6" >64.18</td>
#       <td id="T_d6a48_row2_col7" class="data row2 col7" >-51.74</td>
#     </tr>
#     <tr>
#       <td id="T_d6a48_row3_col0" class="data row3 col0" >Finland</td>
#       <td id="T_d6a48_row3_col1" class="data row3 col1" >FI</td>
#       <td id="T_d6a48_row3_col2" class="data row3 col2" >FIN</td>
#       <td id="T_d6a48_row3_col3" class="data row3 col3" >Helsinki</td>
#       <td id="T_d6a48_row3_col4" class="data row3 col4" >Europe</td>
#       <td id="T_d6a48_row3_col5" class="data row3 col5" >Northern Europe</td>
#       <td id="T_d6a48_row3_col6" class="data row3 col6" >60.17</td>
#       <td id="T_d6a48_row3_col7" class="data row3 col7" >24.94</td>
#     </tr>
#     <tr>
#       <td id="T_d6a48_row4_col0" class="data row4 col0" >Uganda</td>
#       <td id="T_d6a48_row4_col1" class="data row4 col1" >UG</td>
#       <td id="T_d6a48_row4_col2" class="data row4 col2" >UGA</td>
#       <td id="T_d6a48_row4_col3" class="data row4 col3" >Kampala</td>
#       <td id="T_d6a48_row4_col4" class="data row4 col4" >Africa</td>
#       <td id="T_d6a48_row4_col5" class="data row4 col5" >Eastern Africa</td>
#       <td id="T_d6a48_row4_col6" class="data row4 col6" >0.32</td>
#       <td id="T_d6a48_row4_col7" class="data row4 col7" >32.58</td>
#     </tr>
#     <tr>
#       <td id="T_d6a48_row5_col0" class="data row5 col0" >Montserrat</td>
#       <td id="T_d6a48_row5_col1" class="data row5 col1" >MS</td>
#       <td id="T_d6a48_row5_col2" class="data row5 col2" >MSR</td>
#       <td id="T_d6a48_row5_col3" class="data row5 col3" >Plymouth</td>
#       <td id="T_d6a48_row5_col4" class="data row5 col4" >Americas</td>
#       <td id="T_d6a48_row5_col5" class="data row5 col5" >Caribbean</td>
#       <td id="T_d6a48_row5_col6" class="data row5 col6" >50.37</td>
#       <td id="T_d6a48_row5_col7" class="data row5 col7" >-4.14</td>
#     </tr>
#     <tr>
#       <td id="T_d6a48_row6_col0" class="data row6 col0" >Solomon Islands</td>
#       <td id="T_d6a48_row6_col1" class="data row6 col1" >SB</td>
#       <td id="T_d6a48_row6_col2" class="data row6 col2" >SLB</td>
#       <td id="T_d6a48_row6_col3" class="data row6 col3" >Honiara</td>
#       <td id="T_d6a48_row6_col4" class="data row6 col4" >Oceania</td>
#       <td id="T_d6a48_row6_col5" class="data row6 col5" >Melanesia</td>
#       <td id="T_d6a48_row6_col6" class="data row6 col6" >-9.43</td>
#       <td id="T_d6a48_row6_col7" class="data row6 col7" >159.96</td>
#     </tr>
#     <tr>
#       <td id="T_d6a48_row7_col0" class="data row7 col0" >Panama</td>
#       <td id="T_d6a48_row7_col1" class="data row7 col1" >PA</td>
#       <td id="T_d6a48_row7_col2" class="data row7 col2" >PAN</td>
#       <td id="T_d6a48_row7_col3" class="data row7 col3" >Panama City</td>
#       <td id="T_d6a48_row7_col4" class="data row7 col4" >Americas</td>
#       <td id="T_d6a48_row7_col5" class="data row7 col5" >Central America</td>
#       <td id="T_d6a48_row7_col6" class="data row7 col6" >8.97</td>
#       <td id="T_d6a48_row7_col7" class="data row7 col7" >-79.53</td>
#     </tr>
#     <tr>
#       <td id="T_d6a48_row8_col0" class="data row8 col0" >Mayotte</td>
#       <td id="T_d6a48_row8_col1" class="data row8 col1" >YT</td>
#       <td id="T_d6a48_row8_col2" class="data row8 col2" >MYT</td>
#       <td id="T_d6a48_row8_col3" class="data row8 col3" >Mamoudzou</td>
#       <td id="T_d6a48_row8_col4" class="data row8 col4" >Africa</td>
#       <td id="T_d6a48_row8_col5" class="data row8 col5" >Eastern Africa</td>
#       <td id="T_d6a48_row8_col6" class="data row8 col6" >-12.78</td>
#       <td

# %% [markdown]
# ## **3.3: Aircraft Types**

# %%
captionString \
    = 'Table 3.3: Aircraft Types DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (typesDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_46f87 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_46f87_row0_col0, #T_46f87_row1_col0, #T_46f87_row2_col0, #T_46f87_row3_col0, #T_46f87_row4_col0, #T_46f87_row5_col0, #T_46f87_row6_col0, #T_46f87_row7_col0, #T_46f87_row8_col0, #T_46f87_row9_col0, #T_46f87_row10_col0, #T_46f87_row11_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_46f87">
#   <caption>Table 3.3: Aircraft Types DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_46f87_level0_col0" class="col_heading level0 col0" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46f87_row0_col0" class="data row0 col0" >ATR 42</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row1_col0" class="data row1 col0" >ATR 72</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row2_col0" class="data row2 col0" >Aero Spacelines 377</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row3_col0" class="data row3 col0" >Airbus A300</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row4_col0" class="data row4 col0" >Airbus A320</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row5_col0" class="data row5 col0" >Airbus A400</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row6_col0" class="data row6 col0" >Antonov AN-10</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row7_col0" class="data row7 col0" >Antonov AN-12</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row8_col0" class="data row8 col0" >Antonov AN-124</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row9_col0" class="data row9 col0" >Antonov AN-2</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row10_col0" class="data row10 col0" >Antonov AN-22</td>
#     </tr>
#     <tr>
#       <td id="T_46f87_row11_col0" class="data row11 col0" >Antonov AN-24</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **3.4: Aircraft Operators**

# %%
captionString \
    = 'Table 3.4: Aircraft Operators DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (operatorsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_8ef1f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_8ef1f_row0_col0, #T_8ef1f_row1_col0, #T_8ef1f_row2_col0, #T_8ef1f_row3_col0, #T_8ef1f_row4_col0, #T_8ef1f_row5_col0, #T_8ef1f_row6_col0, #T_8ef1f_row7_col0, #T_8ef1f_row8_col0, #T_8ef1f_row9_col0, #T_8ef1f_row10_col0, #T_8ef1f_row11_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_8ef1f">
#   <caption>Table 3.4: Aircraft Operators DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_8ef1f_level0_col0" class="col_heading level0 col0" >operator</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8ef1f_row0_col0" class="data row0 col0" >A & H Aircraft Sales</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row1_col0" class="data row1 col0" >A. McVinish</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row2_col0" class="data row2 col0" >ACE Air Cargo</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row3_col0" class="data row3 col0" >ADC Airlines</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row4_col0" class="data row4 col0" >AIRES Colombia</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row5_col0" class="data row5 col0" >ATI Aircompany</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row6_col0" class="data row6 col0" >AVENSA</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row7_col0" class="data row7 col0" >Abakan Airlines</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row8_col0" class="data row8 col0" >Aeolus Air Charter</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row9_col0" class="data row9 col0" >AereoServicio Guerrero</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row10_col0" class="data row10 col0" >Aeriantur-M Airlines</td>
#     </tr>
#     <tr>
#       <td id="T_8ef1f_row11_col0" class="data row11 col0" >Aero Club Libya</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **3.5: Aircraft Damage**

# %%
captionString \
    = 'Table 3.5: Aircraft Damage DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (damageDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_563e9 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_563e9_row0_col0, #T_563e9_row1_col0, #T_563e9_row2_col0, #T_563e9_row3_col0, #T_563e9_row4_col0, #T_563e9_row5_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_563e9">
#   <caption>Table 3.5: Aircraft Damage DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_563e9_level0_col0" class="col_heading level0 col0" >damage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_563e9_row0_col0" class="data row0 col0" >Damaged beyond repair</td>
#     </tr>
#     <tr>
#       <td id="T_563e9_row1_col0" class="data row1 col0" >Destroyed</td>
#     </tr>
#     <tr>
#       <td id="T_563e9_row2_col0" class="data row2 col0" >Minor</td>
#     </tr>
#     <tr>
#       <td id="T_563e9_row3_col0" class="data row3 col0" >Missing</td>
#     </tr>
#     <tr>
#       <td id="T_563e9_row4_col0" class="data row4 col0" >Substantial</td>
#     </tr>
#     <tr>
#       <td id="T_563e9_row5_col0" class="data row5 col0" >Unknown</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **3.6: Flight Phase**

# %%
captionString \
    = 'Table 3.6: Flight Phase DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (phaseDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_5cfec caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_5cfec_row0_col0, #T_5cfec_row1_col0, #T_5cfec_row2_col0, #T_5cfec_row3_col0, #T_5cfec_row4_col0, #T_5cfec_row5_col0, #T_5cfec_row6_col0, #T_5cfec_row7_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_5cfec">
#   <caption>Table 3.6: Flight Phase DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_5cfec_level0_col0" class="col_heading level0 col0" >phase</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5cfec_row0_col0" class="data row0 col0" >Approach (APR)</td>
#     </tr>
#     <tr>
#       <td id="T_5cfec_row1_col0" class="data row1 col0" >En route (ENR)</td>
#     </tr>
#     <tr>
#       <td id="T_5cfec_row2_col0" class="data row2 col0" >Initial climb (ICL)</td>
#     </tr>
#     <tr>
#       <td id="T_5cfec_row3_col0" class="data row3 col0" >Landing (LDG)</td>
#     </tr>
#     <tr>
#       <td id="T_5cfec_row4_col0" class="data row4 col0" >Maneuvering (MNV)</td>
#     </tr>
#     <tr>
#       <td id="T_5cfec_row5_col0" class="data row5 col0" >Standing (STD)</td>
#     </tr>
#     <tr>
#       <td id="T_5cfec_row6_col0" class="data row6 col0" >Takeoff (TOF)</td>
#     </tr>
#     <tr>
#       <td id="T_5cfec_row7_col0" class="data row7 col0" >Unknown (UNK)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **3.7: Nature of Flight**

# %%
captionString \
    = 'Table 3.7: Nature of Flight DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (natureDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_1d8d0 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_1d8d0_row0_col0, #T_1d8d0_row1_col0, #T_1d8d0_row2_col0, #T_1d8d0_row3_col0, #T_1d8d0_row4_col0, #T_1d8d0_row5_col0, #T_1d8d0_row6_col0, #T_1d8d0_row7_col0, #T_1d8d0_row8_col0, #T_1d8d0_row9_col0, #T_1d8d0_row10_col0, #T_1d8d0_row11_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_1d8d0">
#   <caption>Table 3.7: Nature of Flight DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_1d8d0_level0_col0" class="col_heading level0 col0" >nature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1d8d0_row0_col0" class="data row0 col0" >Aerial Work (Calibration, Photo)</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row1_col0" class="data row1 col0" >Agricultural</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row2_col0" class="data row2 col0" >Ambulance</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row3_col0" class="data row3 col0" >Cargo</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row4_col0" class="data row4 col0" >Demonstration</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row5_col0" class="data row5 col0" >Domestic Non Scheduled Passenger</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row6_col0" class="data row6 col0" >Domestic Scheduled Passenger</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row7_col0" class="data row7 col0" >Executive</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row8_col0" class="data row8 col0" >Ferry/positioning</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row9_col0" class="data row9 col0" >Fire fighting</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row10_col0" class="data row10 col0" >Illegal Flight</td>
#     </tr>
#     <tr>
#       <td id="T_1d8d0_row11_col0" class="data row11 col0" >Int'l Non Scheduled Passenger</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **3.8: Airports**

# %%
captionString \
    = 'Table 3.8: Airports DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (airportsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_d81d4 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d81d4_row0_col0, #T_d81d4_row0_col1, #T_d81d4_row0_col2, #T_d81d4_row0_col3, #T_d81d4_row0_col4, #T_d81d4_row0_col5, #T_d81d4_row0_col6, #T_d81d4_row0_col7, #T_d81d4_row1_col0, #T_d81d4_row1_col1, #T_d81d4_row1_col2, #T_d81d4_row1_col3, #T_d81d4_row1_col4, #T_d81d4_row1_col5, #T_d81d4_row1_col6, #T_d81d4_row1_col7, #T_d81d4_row2_col0, #T_d81d4_row2_col1, #T_d81d4_row2_col2, #T_d81d4_row2_col3, #T_d81d4_row2_col4, #T_d81d4_row2_col5, #T_d81d4_row2_col6, #T_d81d4_row2_col7, #T_d81d4_row3_col0, #T_d81d4_row3_col1, #T_d81d4_row3_col2, #T_d81d4_row3_col3, #T_d81d4_row3_col4, #T_d81d4_row3_col5, #T_d81d4_row3_col6, #T_d81d4_row3_col7, #T_d81d4_row4_col0, #T_d81d4_row4_col1, #T_d81d4_row4_col2, #T_d81d4_row4_col3, #T_d81d4_row4_col4, #T_d81d4_row4_col5, #T_d81d4_row4_col6, #T_d81d4_row4_col7, #T_d81d4_row5_col0, #T_d81d4_row5_col1, #T_d81d4_row5_col2, #T_d81d4_row5_col3, #T_d81d4_row5_col4, #T_d81d4_row5_col5, #T_d81d4_row5_col6, #T_d81d4_row5_col7, #T_d81d4_row6_col0, #T_d81d4_row6_col1, #T_d81d4_row6_col2, #T_d81d4_row6_col3, #T_d81d4_row6_col4, #T_d81d4_row6_col5, #T_d81d4_row6_col6, #T_d81d4_row6_col7, #T_d81d4_row7_col0, #T_d81d4_row7_col1, #T_d81d4_row7_col2, #T_d81d4_row7_col3, #T_d81d4_row7_col4, #T_d81d4_row7_col5, #T_d81d4_row7_col6, #T_d81d4_row7_col7, #T_d81d4_row8_col0, #T_d81d4_row8_col1, #T_d81d4_row8_col2, #T_d81d4_row8_col3, #T_d81d4_row8_col4, #T_d81d4_row8_col5, #T_d81d4_row8_col6, #T_d81d4_row8_col7, #T_d81d4_row9_col0, #T_d81d4_row9_col1, #T_d81d4_row9_col2, #T_d81d4_row9_col3, #T_d81d4_row9_col4, #T_d81d4_row9_col5, #T_d81d4_row9_col6, #T_d81d4_row9_col7, #T_d81d4_row10_col0, #T_d81d4_row10_col1, #T_d81d4_row10_col2, #T_d81d4_row10_col3, #T_d81d4_row10_col4, #T_d81d4_row10_col5, #T_d81d4_row10_col6, #T_d81d4_row10_col7, #T_d81d4_row11_col0, #T_d81d4_row11_col1, #T_d81d4_row11_col2, #T_d81d4_row11_col3, #T_d81d4_row11_col4, #T_d81d4_row11_col5, #T_d81d4_row11_col6, #T_d81d4_row11_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_d81d4">
#   <caption>Table 3.8: Airports DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_d81d4_level0_col0" class="col_heading level0 col0" >icao</th>
#       <th id="T_d81d4_level0_col1" class="col_heading level0 col1" >iata</th>
#       <th id="T_d81d4_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_d81d4_level0_col3" class="col_heading level0 col3" >state</th>
#       <th id="T_d81d4_level0_col4" class="col_heading level0 col4" >country</th>
#       <th id="T_d81d4_level0_col5" class="col_heading level0 col5" >country_code</th>
#       <th id="T_d81d4_level0_col6" class="col_heading level0 col6" >lat</th>
#       <th id="T_d81d4_level0_col7" class="col_heading level0 col7" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d81d4_row0_col0" class="data row0 col0" >ZSNJ</td>
#       <td id="T_d81d4_row0_col1" class="data row0 col1" >NKG</td>
#       <td id="T_d81d4_row0_col2" class="data row0 col2" >Nanjing Dajiaochang Airport</td>
#       <td id="T_d81d4_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_d81d4_row0_col4" class="data row0 col4" >China</td>
#       <td id="T_d81d4_row0_col5" class="data row0 col5" >CN</td>
#       <td id="T_d81d4_row0_col6" class="data row0 col6" >31.74</td>
#       <td id="T_d81d4_row0_col7" class="data row0 col7" >118.86</td>
#     </tr>
#     <tr>
#       <td id="T_d81d4_row1_col0" class="data row1 col0" >UKCC</td>
#       <td id="T_d81d4_row1_col1" class="data row1 col1" >DOK</td>
#       <td id="T_d81d4_row1_col2" class="data row1 col2" >Donetsk Airport</td>
#       <td id="T_d81d4_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_d81d4_row1_col4" class="data row1 col4" >Ukraine</td>
#       <td id="T_d81d4_row1_col5" class="data row1 col5" >UA</td>
#       <td id="T_d81d4_row1_col6" class="data row1 col6" >48.07</td>
#       <td id="T_d81d4_row1_col7" class="data row1 col7" >37.74</td>
#     </tr>
#     <tr>
#       <td id="T_d81d4_row2_col0" class="data row2 col0" >GYGM</td>
#       <td id="T_d81d4_row2_col1" class="data row2 col1" >YGM</td>
#       <td id="T_d81d4_row2_col2" class="data row2 col2" >Gimli Airport</td>
#       <td id="T_d81d4_row2_col3" class="data row2 col3" >MB</td>
#       <td id="T_d81d4_row2_col4" class="data row2 col4" >Canada</td>
#       <td id="T_d81d4_row2_col5" class="data row2 col5" >CA</td>
#       <td id="T_d81d4_row2_col6" class="data row2 col6" >50.63</td>
#       <td id="T_d81d4_row2_col7" class="data row2 col7" >-97.04</td>
#     </tr>
#     <tr>
#       <td id="T_d81d4_row3_col0" class="data row3 col0" >SPQT</td>
#       <td id="T_d81d4_row3_col1" class="data row3 col1" >IQT</td>
#       <td id="T_d81d4_row3_col2" class="data row3 col2" >Iquitos Airport</td>
#       <td id="T_d81d4_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_d81d4_row3_col4" class="data row3 col4" >Peru</td>
#       <td id="T_d81d4_row3_col5" class="data row3 col5" >PE</td>
#       <td id="T_d81d4_row3_col6" class="data row3 col6" >-3.78</td>
#       <td id="T_d81d4_row3_col7" class="data row3 col7" >-73.31</td>
#     </tr>
#     <tr>
#       <td id="T_d81d4_row4_col0" class="data row4 col0" >SPST</td>
#       <td id="T_d81d4_row4_col1" class="data row4 col1" >TPP</td>
#       <td id="T_d81d4_row4_col2" class="data row4 col2" >Tarapoto Airport</td>
#       <td id="T_d81d4_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_d81d4_row4_col4" class="data row4 col4" >Peru</td>
#       <td id="T_d81d4_row4_col5" class="data row4 col5" >PE</td>
#       <td id="T_d81d4_row4_col6" class="data row4 col6" >-6.51</td>
#       <td id="T_d81d4_row4_col7" class="data row4 col7" >-76.37</td>
#     </tr>
#     <tr>
#       <td id="T_d81d4_row5_col0" class="data row5 col0" >KSCK</td>
#       <td id="T_d81d4_row5_col1" class="data row5 col1" >SCK</td>
#       <td id="T_d81d4_row5_col2" class="data row5 col2" >Stockton Airport</td>
#       <td id="T_d81d4_row5_col3" class="data row5 col3" >CA</td>
#       <td id="T_d81d4_row5_col4" class="data row5 col4" >United States of America</td>
#       <td id="T_d81d4_row5_col5" class="data row5 col5" >US</td>
#       <td id="T_d81d4_row5_col6" class="data row5 col6" >37.89</td>
#       <td id="T_d81d4_row5_col7" class="data row5 col7" >-121.24</td>
#     </tr>
#     <tr>
#       <td id="T_d81d4_row6_col0" class="data row6 col0" >MMPN</td>
#       <td id="T_d81d4_row6_col1" class="data row6 col1" >UPN</td>
#       <td id="T_d81d4_row6_col2" class="data row6 col2" >Uruapan Airport</td>
#       <td id="T_d81d4_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_d81d4_row6_col4" class="data row6 col4" >Mexico</td>
#       <td id="T_d81d4_row6_col5" class="data row6 col5" >MX</td>
#       <td id="T_d81d4_row6_col6" class="data row6 col6" >19.40</td>
#       <td id="T_d81d4_row6_col7" class="data row6 col7" >-102.04</td>
#     </tr>
#     <tr>
#       <td id="T_d81d4_row7_col0" class="data row7 col0" >KDAY</td>
#       <td id="T_d81d4_row7_col1" class="data row7 col1" >DAY</td>
#       <td id="T_d81d4_row7_col2" class="data row7 col2" >Dayton Airport</td>
#       <td id="T_d81d4_row7_col3" class="data row7 col3" >OH</td>
#       <td id="T_d81d4_row7_col4" class="data row7 col4" >United States of America</td>
#       <td id="T_d81d4_row7_col5" class="data row7 col5" >US</td>
#       <td id="T_d81d4_row7_col6" class="data row7 col6" >39.90</td>
#       <td id="T_d81d4_row7_col7" class="data row7 col7" >-84.22</td>
#     </tr>
#     <tr>
#       <td id="T_d81d4_row8_col0" class="data row8 col0" >FZOA</td>
#       <td id="T_d81d4_row8_col1" class="data row8 col1" >KND</td>
#       <td id="T_d81d4_row8_col2" class="data row8 col2" >Kindu Airport</td>
#       <td id="T_d81d4_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_d81d4_row8_col4" class="data row8 col4" >Democratic Republic of the Congo</td>
#       <td id="T_d81d4_row8_col5" class="data row8 col5" >CD</td>
#       <td id="T_d81d4_row8_col6" class="data row8 col6" >-2.92</td>
#       <td id="T_d81d4

# %% [markdown]
# ## **3.9: Departure Airports**

# %%
captionString \
    = 'Table 3.9: Departure Airports DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (updatedDepartureAirportsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_91efc caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_91efc_row0_col0, #T_91efc_row0_col1, #T_91efc_row0_col2, #T_91efc_row0_col3, #T_91efc_row0_col4, #T_91efc_row0_col5, #T_91efc_row0_col6, #T_91efc_row0_col7, #T_91efc_row0_col8, #T_91efc_row0_col9, #T_91efc_row0_col10, #T_91efc_row1_col0, #T_91efc_row1_col1, #T_91efc_row1_col2, #T_91efc_row1_col3, #T_91efc_row1_col4, #T_91efc_row1_col5, #T_91efc_row1_col6, #T_91efc_row1_col7, #T_91efc_row1_col8, #T_91efc_row1_col9, #T_91efc_row1_col10, #T_91efc_row2_col0, #T_91efc_row2_col1, #T_91efc_row2_col2, #T_91efc_row2_col3, #T_91efc_row2_col4, #T_91efc_row2_col5, #T_91efc_row2_col6, #T_91efc_row2_col7, #T_91efc_row2_col8, #T_91efc_row2_col9, #T_91efc_row2_col10, #T_91efc_row3_col0, #T_91efc_row3_col1, #T_91efc_row3_col2, #T_91efc_row3_col3, #T_91efc_row3_col4, #T_91efc_row3_col5, #T_91efc_row3_col6, #T_91efc_row3_col7, #T_91efc_row3_col8, #T_91efc_row3_col9, #T_91efc_row3_col10, #T_91efc_row4_col0, #T_91efc_row4_col1, #T_91efc_row4_col2, #T_91efc_row4_col3, #T_91efc_row4_col4, #T_91efc_row4_col5, #T_91efc_row4_col6, #T_91efc_row4_col7, #T_91efc_row4_col8, #T_91efc_row4_col9, #T_91efc_row4_col10, #T_91efc_row5_col0, #T_91efc_row5_col1, #T_91efc_row5_col2, #T_91efc_row5_col3, #T_91efc_row5_col4, #T_91efc_row5_col5, #T_91efc_row5_col6, #T_91efc_row5_col7, #T_91efc_row5_col8, #T_91efc_row5_col9, #T_91efc_row5_col10, #T_91efc_row6_col0, #T_91efc_row6_col1, #T_91efc_row6_col2, #T_91efc_row6_col3, #T_91efc_row6_col4, #T_91efc_row6_col5, #T_91efc_row6_col6, #T_91efc_row6_col7, #T_91efc_row6_col8, #T_91efc_row6_col9, #T_91efc_row6_col10, #T_91efc_row7_col0, #T_91efc_row7_col1, #T_91efc_row7_col2, #T_91efc_row7_col3, #T_91efc_row7_col4, #T_91efc_row7_col5, #T_91efc_row7_col6, #T_91efc_row7_col7, #T_91efc_row7_col8, #T_91efc_row7_col9, #T_91efc_row7_col10, #T_91efc_row8_col0, #T_91efc_row8_col1, #T_91efc_row8_col2, #T_91efc_row8_col3, #T_91efc_row8_col4, #T_91efc_row8_col5, #T_91efc_row8_col6, #T_91efc_row8_col7, #T_91efc_row8_col8, #T_91efc_row8_col9, #T_91efc_row8_col10, #T_91efc_row9_col0, #T_91efc_row9_col1, #T_91efc_row9_col2, #T_91efc_row9_col3, #T_91efc_row9_col4, #T_91efc_row9_col5, #T_91efc_row9_col6, #T_91efc_row9_col7, #T_91efc_row9_col8, #T_91efc_row9_col9, #T_91efc_row9_col10, #T_91efc_row10_col0, #T_91efc_row10_col1, #T_91efc_row10_col2, #T_91efc_row10_col3, #T_91efc_row10_col4, #T_91efc_row10_col5, #T_91efc_row10_col6, #T_91efc_row10_col7, #T_91efc_row10_col8, #T_91efc_row10_col9, #T_91efc_row10_col10, #T_91efc_row11_col0, #T_91efc_row11_col1, #T_91efc_row11_col2, #T_91efc_row11_col3, #T_91efc_row11_col4, #T_91efc_row11_col5, #T_91efc_row11_col6, #T_91efc_row11_col7, #T_91efc_row11_col8, #T_91efc_row11_col9, #T_91efc_row11_col10 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_91efc">
#   <caption>Table 3.9: Departure Airports DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_91efc_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_91efc_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_91efc_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_91efc_level0_col3" class="col_heading level0 col3" >icao</th>
#       <th id="T_91efc_level0_col4" class="col_heading level0 col4" >iata</th>
#       <th id="T_91efc_level0_col5" class="col_heading level0 col5" >name</th>
#       <th id="T_91efc_level0_col6" class="col_heading level0 col6" >state</th>
#       <th id="T_91efc_level0_col7" class="col_heading level0 col7" >country</th>
#       <th id="T_91efc_level0_col8" class="col_heading level0 col8" >country_code</th>
#       <th id="T_91efc_level0_col9" class="col_heading level0 col9" >lat</th>
#       <th id="T_91efc_level0_col10" class="col_heading level0 col10" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_91efc_row0_col0" class="data row0 col0" >ACC1003</td>
#       <td id="T_91efc_row0_col1" class="data row0 col1" >1992-07-31</td>
#       <td id="T_91efc_row0_col2" class="data row0 col2" >1992</td>
#       <td id="T_91efc_row0_col3" class="data row0 col3" >ZSNJ</td>
#       <td id="T_91efc_row0_col4" class="data row0 col4" >NKG</td>
#       <td id="T_91efc_row0_col5" class="data row0 col5" >Nanjing Dajiaochang Airport</td>
#       <td id="T_91efc_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_91efc_row0_col7" class="data row0 col7" >China</td>
#       <td id="T_91efc_row0_col8" class="data row0 col8" >CN</td>
#       <td id="T_91efc_row0_col9" class="data row0 col9" >31.74</td>
#       <td id="T_91efc_row0_col10" class="data row0 col10" >118.86</td>
#     </tr>
#     <tr>
#       <td id="T_91efc_row1_col0" class="data row1 col0" >ACC1004</td>
#       <td id="T_91efc_row1_col1" class="data row1 col1" >1992-08-27</td>
#       <td id="T_91efc_row1_col2" class="data row1 col2" >1992</td>
#       <td id="T_91efc_row1_col3" class="data row1 col3" >UKCC</td>
#       <td id="T_91efc_row1_col4" class="data row1 col4" >DOK</td>
#       <td id="T_91efc_row1_col5" class="data row1 col5" >Donetsk Airport</td>
#       <td id="T_91efc_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_91efc_row1_col7" class="data row1 col7" >Ukraine</td>
#       <td id="T_91efc_row1_col8" class="data row1 col8" >UA</td>
#       <td id="T_91efc_row1_col9" class="data row1 col9" >48.07</td>
#       <td id="T_91efc_row1_col10" class="data row1 col10" >37.74</td>
#     </tr>
#     <tr>
#       <td id="T_91efc_row2_col0" class="data row2 col0" >ACC1005</td>
#       <td id="T_91efc_row2_col1" class="data row2 col1" >1992-08-27</td>
#       <td id="T_91efc_row2_col2" class="data row2 col2" >1992</td>
#       <td id="T_91efc_row2_col3" class="data row2 col3" >GYGM</td>
#       <td id="T_91efc_row2_col4" class="data row2 col4" >YGM</td>
#       <td id="T_91efc_row2_col5" class="data row2 col5" >Gimli Airport</td>
#       <td id="T_91efc_row2_col6" class="data row2 col6" >MB</td>
#       <td id="T_91efc_row2_col7" class="data row2 col7" >Canada</td>
#       <td id="T_91efc_row2_col8" class="data row2 col8" >CA</td>
#       <td id="T_91efc_row2_col9" class="data row2 col9" >50.63</td>
#       <td id="T_91efc_row2_col10" class="data row2 col10" >-97.04</td>
#     </tr>
#     <tr>
#       <td id="T_91efc_row3_col0" class="data row3 col0" >ACC1006</td>
#       <td id="T_91efc_row3_col1" class="data row3 col1" >1992-08-27</td>
#       <td id="T_91efc_row3_col2" class="data row3 col2" >1992</td>
#       <td id="T_91efc_row3_col3" class="data row3 col3" >SPQT</td>
#       <td id="T_91efc_row3_col4" class="data row3 col4" >IQT</td>
#       <td id="T_91efc_row3_col5" class="data row3 col5" >Iquitos Airport</td>
#       <td id="T_91efc_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_91efc_row3_col7" class="data row3 col7" >Peru</td>
#       <td id="T_91efc_row3_col8" class="data row3 col8" >PE</td>
#       <td id="T_91efc_row3_col9" class="data row3 col9" >-3.78</td>
#       <td id="T_91efc_row3_col10" class="data row3 col10" >-73.31</td>
#     </tr>
#     <tr>
#       <td id="T_91efc_row4_col0" class="data row4 col0" >ACC1010</td>
#       <td id="T_91efc_row4_col1" class="data row4 col1" >1992-09-10</td>
#       <td id="T_91efc_row4_col2" class="data row4 col2" >1992</td>
#       <td id="T_91efc_row4_col3" class="data row4 col3" >SPST</td>
#       <td id="T_91efc_row4_col4" class="data row4 col4" >TPP</td>
#       <td id="T_91efc_row4_col5" class="data row4 col5" >Tarapoto Airport</td>
#       <td id="T_91efc_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_91efc_row4_col7" class="data row4 col7" >Peru</td>
#       <td id="T_91efc_row4_col8" class="data row4 col8" >PE</td>
#       <td id="T_91efc_row4_col9" class="data row4 col9" >-6.51</td>
#       <td id="T_91efc_row4_col10" class="data row4 col10" >-76.37</td>
#     </tr>
#     <tr>
#       <td id="T_91efc_row5_col0" class="data row5 col0" >ACC1013</td>
#       <td id="T_91efc_row5_col1" class="data row5 col1" >1992-10-01</td>
#       <td id="T_91efc_row5_col2" class="data row5 col2" >1992</td>

# %% [markdown]
# ## **3.10: Destination Airports**

# %%
captionString \
    = 'Table 3.10: Destination Airports DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (updatedDestinationAirportsDataFrame.head(12), 
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_429aa caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_429aa_row0_col0, #T_429aa_row0_col1, #T_429aa_row0_col2, #T_429aa_row0_col3, #T_429aa_row0_col4, #T_429aa_row0_col5, #T_429aa_row0_col6, #T_429aa_row0_col7, #T_429aa_row0_col8, #T_429aa_row0_col9, #T_429aa_row0_col10, #T_429aa_row1_col0, #T_429aa_row1_col1, #T_429aa_row1_col2, #T_429aa_row1_col3, #T_429aa_row1_col4, #T_429aa_row1_col5, #T_429aa_row1_col6, #T_429aa_row1_col7, #T_429aa_row1_col8, #T_429aa_row1_col9, #T_429aa_row1_col10, #T_429aa_row2_col0, #T_429aa_row2_col1, #T_429aa_row2_col2, #T_429aa_row2_col3, #T_429aa_row2_col4, #T_429aa_row2_col5, #T_429aa_row2_col6, #T_429aa_row2_col7, #T_429aa_row2_col8, #T_429aa_row2_col9, #T_429aa_row2_col10, #T_429aa_row3_col0, #T_429aa_row3_col1, #T_429aa_row3_col2, #T_429aa_row3_col3, #T_429aa_row3_col4, #T_429aa_row3_col5, #T_429aa_row3_col6, #T_429aa_row3_col7, #T_429aa_row3_col8, #T_429aa_row3_col9, #T_429aa_row3_col10, #T_429aa_row4_col0, #T_429aa_row4_col1, #T_429aa_row4_col2, #T_429aa_row4_col3, #T_429aa_row4_col4, #T_429aa_row4_col5, #T_429aa_row4_col6, #T_429aa_row4_col7, #T_429aa_row4_col8, #T_429aa_row4_col9, #T_429aa_row4_col10, #T_429aa_row5_col0, #T_429aa_row5_col1, #T_429aa_row5_col2, #T_429aa_row5_col3, #T_429aa_row5_col4, #T_429aa_row5_col5, #T_429aa_row5_col6, #T_429aa_row5_col7, #T_429aa_row5_col8, #T_429aa_row5_col9, #T_429aa_row5_col10, #T_429aa_row6_col0, #T_429aa_row6_col1, #T_429aa_row6_col2, #T_429aa_row6_col3, #T_429aa_row6_col4, #T_429aa_row6_col5, #T_429aa_row6_col6, #T_429aa_row6_col7, #T_429aa_row6_col8, #T_429aa_row6_col9, #T_429aa_row6_col10, #T_429aa_row7_col0, #T_429aa_row7_col1, #T_429aa_row7_col2, #T_429aa_row7_col3, #T_429aa_row7_col4, #T_429aa_row7_col5, #T_429aa_row7_col6, #T_429aa_row7_col7, #T_429aa_row7_col8, #T_429aa_row7_col9, #T_429aa_row7_col10, #T_429aa_row8_col0, #T_429aa_row8_col1, #T_429aa_row8_col2, #T_429aa_row8_col3, #T_429aa_row8_col4, #T_429aa_row8_col5, #T_429aa_row8_col6, #T_429aa_row8_col7, #T_429aa_row8_col8, #T_429aa_row8_col9, #T_429aa_row8_col10, #T_429aa_row9_col0, #T_429aa_row9_col1, #T_429aa_row9_col2, #T_429aa_row9_col3, #T_429aa_row9_col4, #T_429aa_row9_col5, #T_429aa_row9_col6, #T_429aa_row9_col7, #T_429aa_row9_col8, #T_429aa_row9_col9, #T_429aa_row9_col10, #T_429aa_row10_col0, #T_429aa_row10_col1, #T_429aa_row10_col2, #T_429aa_row10_col3, #T_429aa_row10_col4, #T_429aa_row10_col5, #T_429aa_row10_col6, #T_429aa_row10_col7, #T_429aa_row10_col8, #T_429aa_row10_col9, #T_429aa_row10_col10, #T_429aa_row11_col0, #T_429aa_row11_col1, #T_429aa_row11_col2, #T_429aa_row11_col3, #T_429aa_row11_col4, #T_429aa_row11_col5, #T_429aa_row11_col6, #T_429aa_row11_col7, #T_429aa_row11_col8, #T_429aa_row11_col9, #T_429aa_row11_col10 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_429aa">
#   <caption>Table 3.10: Destination Airports DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_429aa_level0_col0" class="col_heading level0 col0" >accident_id</th>
#       <th id="T_429aa_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_429aa_level0_col2" class="col_heading level0 col2" >year</th>
#       <th id="T_429aa_level0_col3" class="col_heading level0 col3" >icao</th>
#       <th id="T_429aa_level0_col4" class="col_heading level0 col4" >iata</th>
#       <th id="T_429aa_level0_col5" class="col_heading level0 col5" >name</th>
#       <th id="T_429aa_level0_col6" class="col_heading level0 col6" >state</th>
#       <th id="T_429aa_level0_col7" class="col_heading level0 col7" >country</th>
#       <th id="T_429aa_level0_col8" class="col_heading level0 col8" >country_code</th>
#       <th id="T_429aa_level0_col9" class="col_heading level0 col9" >lat</th>
#       <th id="T_429aa_level0_col10" class="col_heading level0 col10" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_429aa_row0_col0" class="data row0 col0" >ACC1003</td>
#       <td id="T_429aa_row0_col1" class="data row0 col1" >1992-07-31</td>
#       <td id="T_429aa_row0_col2" class="data row0 col2" >1992</td>
#       <td id="T_429aa_row0_col3" class="data row0 col3" >ZSAM</td>
#       <td id="T_429aa_row0_col4" class="data row0 col4" >XMN</td>
#       <td id="T_429aa_row0_col5" class="data row0 col5" >Xiamen Airport</td>
#       <td id="T_429aa_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_429aa_row0_col7" class="data row0 col7" >China</td>
#       <td id="T_429aa_row0_col8" class="data row0 col8" >CN</td>
#       <td id="T_429aa_row0_col9" class="data row0 col9" >24.54</td>
#       <td id="T_429aa_row0_col10" class="data row0 col10" >118.13</td>
#     </tr>
#     <tr>
#       <td id="T_429aa_row1_col0" class="data row1 col0" >ACC1004</td>
#       <td id="T_429aa_row1_col1" class="data row1 col1" >1992-08-27</td>
#       <td id="T_429aa_row1_col2" class="data row1 col2" >1992</td>
#       <td id="T_429aa_row1_col3" class="data row1 col3" >UUBI</td>
#       <td id="T_429aa_row1_col4" class="data row1 col4" >IWA</td>
#       <td id="T_429aa_row1_col5" class="data row1 col5" >Ivanovo Airport</td>
#       <td id="T_429aa_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_429aa_row1_col7" class="data row1 col7" >Russia</td>
#       <td id="T_429aa_row1_col8" class="data row1 col8" >RU</td>
#       <td id="T_429aa_row1_col9" class="data row1 col9" >56.94</td>
#       <td id="T_429aa_row1_col10" class="data row1 col10" >40.94</td>
#     </tr>
#     <tr>
#       <td id="T_429aa_row2_col0" class="data row2 col0" >ACC1005</td>
#       <td id="T_429aa_row2_col1" class="data row2 col1" >1992-08-27</td>
#       <td id="T_429aa_row2_col2" class="data row2 col2" >1992</td>
#       <td id="T_429aa_row2_col3" class="data row2 col3" >GYGM</td>
#       <td id="T_429aa_row2_col4" class="data row2 col4" >YGM</td>
#       <td id="T_429aa_row2_col5" class="data row2 col5" >Gimli Airport</td>
#       <td id="T_429aa_row2_col6" class="data row2 col6" >MB</td>
#       <td id="T_429aa_row2_col7" class="data row2 col7" >Canada</td>
#       <td id="T_429aa_row2_col8" class="data row2 col8" >CA</td>
#       <td id="T_429aa_row2_col9" class="data row2 col9" >50.63</td>
#       <td id="T_429aa_row2_col10" class="data row2 col10" >-97.04</td>
#     </tr>
#     <tr>
#       <td id="T_429aa_row3_col0" class="data row3 col0" >ACC1006</td>
#       <td id="T_429aa_row3_col1" class="data row3 col1" >1992-08-27</td>
#       <td id="T_429aa_row3_col2" class="data row3 col2" >1992</td>
#       <td id="T_429aa_row3_col3" class="data row3 col3" >SPEE</td>
#       <td id="T_429aa_row3_col4" class="data row3 col4" >xxx</td>
#       <td id="T_429aa_row3_col5" class="data row3 col5" >El Estrecho Airport</td>
#       <td id="T_429aa_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_429aa_row3_col7" class="data row3 col7" >Peru</td>
#       <td id="T_429aa_row3_col8" class="data row3 col8" >PE</td>
#       <td id="T_429aa_row3_col9" class="data row3 col9" >-2.45</td>
#       <td id="T_429aa_row3_col10" class="data row3 col10" >-72.67</td>
#     </tr>
#     <tr>
#       <td id="T_429aa_row4_col0" class="data row4 col0" >ACC1010</td>
#       <td id="T_429aa_row4_col1" class="data row4 col1" >1992-09-10</td>
#       <td id="T_429aa_row4_col2" class="data row4 col2" >1992</td>
#       <td id="T_429aa_row4_col3" class="data row4 col3" >SPBL</td>
#       <td id="T_429aa_row4_col4" class="data row4 col4" >BLP</td>
#       <td id="T_429aa_row4_col5" class="data row4 col5" >Bellavista Airport</td>
#       <td id="T_429aa_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_429aa_row4_col7" class="data row4 col7" >Peru</td>
#       <td id="T_429aa_row4_col8" class="data row4 col8" >PE</td>
#       <td id="T_429aa_row4_col9" class="data row4 col9" >-7.06</td>
#       <td id="T_429aa_row4_col10" class="data row4 col10" >-76.58</td>
#     </tr>
#     <tr>
#       <td id="T_429aa_row5_col0" class="data row5 col0" >ACC1013</td>
#       <td id="T_429aa_row5_col1" class="data row5 col1" >1992-10-01</td>
#       <td id="T_429aa_row5_col2" class="data row5 col2" >1992</td>

# %% [markdown]
# # <br> **Section 4: Export DataFrames to CSV Files**

# %% [markdown]
# ## **4.1: Aviation Accidents**

# %%
finalAccidentsDataFrame \
    .to_csv \
        (local_constant \
             .AVIATION_ACCIDENTS_DATABASE_TABLE_CSV_FILE)

# %% [markdown]
# ## **4.2: Country**

# %%
countryDataFrame \
    .to_csv \
        (local_constant \
             .COUNTRY_DATABASE_TABLE_CSV_FILE)

# %% [markdown]
# ## **4.3: Aircraft Types**

# %%
typesDataFrame \
    .to_csv \
        (local_constant \
             .AIRCRAFT_TYPES_DATABASE_TABLE_CSV_FILE)

# %% [markdown]
# ## **4.4: Aircraft Operators**

# %%
operatorsDataFrame \
    .to_csv \
        (local_constant \
             .AIRCRAFT_OPERATORS_DATABASE_TABLE_CSV_FILE)

# %% [markdown]
# ## **4.5: Aircraft Damage**

# %%
damageDataFrame \
    .to_csv \
        (local_constant \
             .AIRCRAFT_DAMAGE_DATABASE_TABLE_CSV_FILE)

# %% [markdown]
# ## **4.6: Flight Phase**

# %%
phaseDataFrame \
    .to_csv \
        (local_constant \
             .FLIGHT_PHASE_DATABASE_TABLE_CSV_FILE)

# %% [markdown]
# ## **4.7: Nature of Flight**

# %%
natureDataFrame \
    .to_csv \
        (local_constant \
             .NATURE_OF_FLIGHT_DATABASE_TABLE_CSV_FILE)

# %% [markdown]
# ## **4.8: Airports**

# %%
airportsDataFrame \
    .to_csv \
        (local_constant \
             .AIRPORTS_DATABASE_TABLE_CSV_FILE)

# %% [markdown]
# ## **4.9: Departure Airports**

# %%
updatedDepartureAirportsDataFrame \
    .to_csv \
        (local_constant \
             .DEPARTURE_AIRPORTS_DATABASE_TABLE_CSV_FILE)

# %% [markdown]
# ## **4.10: Destination Airports**

# %%
updatedDestinationAirportsDataFrame \
    .to_csv \
        (local_constant \
             .DESTINATION_AIRPORTS_DATABASE_TABLE_CSV_FILE)

# %%
#log_subroutine \
#    .EndProgramExecution()
